# %% [markdown]
# # Histórico e Análise de Experimentos de Classificação de Intenções de Busca
#
# Este *notebook* tem como objetivo permitir o registro visual dos experimentos feitos e oferecer um modo de recuperar um experimento e analisar os resultados em mais detalhes.

# %% [markdown]
# ## Bibliotecas e Funções

# %%
# General
import sys
import funcy as fp
from pathlib import Path

# Visualization / Presentation
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import HTML, display

import mlflow
from mlflow.tracking import MlflowClient
import pandas as pd

# Carregar, além de atualizar frequentemente, código personalizado disponível em ../src
# %load_ext autoreload 
# %autoreload 2
sys.path.append(str(Path.cwd().parent))
from src import settings
from src.utils.notebooks import display_side_by_side
from src.pipeline.inference_pipeline import load_model_resources

# Configurações para a exibição de conteúdo do Pandas e das bibliotecas gráficas
# %matplotlib inline 
sns.set(rc={'figure.figsize':(25,10)})
pd.set_option('display.max_rows', None)
pd.set_option("display.max_columns", None)
pd.set_option('max_colwidth', 150)

# %% [markdown]
# ## Recuperação do melhor resultado
#
# Considerando os experimentos feitos no notebook [Classificação de Intenções](04.3_Classificacao_de_Intencoes.ipynb), faz-se a recuperação dos melhores resultados de cada algoritmo, tendo como métrica principal o F1.

# %%
EXPERIMENT_ID = '4'

mlflow_client = MlflowClient()

best_experiments_result = [
    mlflow.search_runs(experiment_ids=[experiment_id], 
                       max_results=100, 
                       order_by=['metrics.F1 DESC'], 
                       filter_string='attributes.status="FINISHED"')
    for experiment_id in [EXPERIMENT_ID]
]

best_results = pd.concat(best_experiments_result, axis=0)

# %% [markdown]
# O melhores resultados recuperados:

# %%
columns_to_show = ['experiment_name', 'tags.mlflow.runName', 'run_id', 'experiment_id', 'params.model_name',
                   'metrics.f1', 'metrics.precision', 'metrics.recall', 'metrics.auc', 'metrics.mc', 'metrics.training_time']

(best_results
 .assign(experiment_name=lambda f: f['experiment_id'].apply(lambda id: mlflow_client.get_experiment(id).name))
 .sort_values(by='metrics.f1', ascending=False)
 .loc[lambda f: ~f['params.model_name'].isna()]
 .drop_duplicates('params.model_name')
 [columns_to_show]  
 .head()
)
# Out:
#                            experiment_name  \
# 7   04_SupervisedQueryIntentClassification
# 31  04_SupervisedQueryIntentClassification
# 85  04_SupervisedQueryIntentClassification
#
#                          tags.mlflow.runName  \
# 7   01_7_Embeddings and Artisanal Feaures_CB
# 31                 01_9_Artisanal Feaures_RF
# 85                       01_2_Embeddings_MLP
#
#                               run_id experiment_id params.model_name  \
# 7   3ff29c0d3a524d9c95612cb0d6de54ab             4                CB
# 31  700237d7c7b3402fa76068e12958c68e             4                RF
# 85  e76250a177c44c5d97e964e05b66334a             4               MLP
#
#     metrics.f1  metrics.precision  metrics.recall  metrics.auc  metrics.mc  \
# 7     0.565854           0.563107        0.568627     0.719285    0.437068
# 31    0.476190           0.400000        0.588235     0.664060    0.291552
# 85    0.475000           0.655172        0.372549     0.657456    0.393416
#
#     metrics.training_time
# 7                3.430026
# 31               0.616521
# 85               1.684383

# %% [markdown]
# ## Restauração de Experimentos
#
# A partir da escolha de uma execução individual, é possível restaurar os elementos utilizados na experimentação para aplicá-los aos dados.

# %%
RUN_ID = '3ff29c0d3a524d9c95612cb0d6de54ab'

preprocessing_model, model, label_encoder = load_model_resources(RUN_ID)

# %% [markdown]
# Para validar o funcionamento da restauração do modelo, parte dos dados de treinamento são recuperados para uma avaliação.

# %%
columns_to_read = ['query', 'intent_class', 'intent_description']

frame = pd.read_csv(Path(settings.DATA_PATH).joinpath('interim', 'query_intent_training.csv'), usecols=columns_to_read)

display_side_by_side([frame.head(10)], ['Conjunto de Dados de Intenções de Busca'])
# Out:
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Conjunto de Dados de Intenções de Busca</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#       <th>intent_class</th>
#       <th>intent_description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>lembrancinha 1 ano</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>pioneiros</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>fibra siliconada</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>vestido 15 anos</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>quadros personalizados com fotos</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>festa de 50 anos</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>brindes de final de ano</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>porta cartao de vacina</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>letras de nomes personalizados</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>futon</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Tendo os dados, é possível refazer a preparação e fazer a predição da intenção de busca de cada elemento.

# %%
frame_slice = frame.sample(50)

# Processa os dados para inferência
features = preprocessing_model.predict(frame_slice)

# Realiza a inferência
frame_slice['pred'] = model.predict(features)

display_side_by_side([frame_slice, 
                      pd.DataFrame(features).describe().T.head(10)], 
                     ['Dados Recuperados e Predição', 
                      f'Features (10 de {features.shape[1]})'])

del frame_slice
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Dados Recuperados e Predição</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#       <th>intent_class</th>
#       <th>intent_description</th>
#       <th>pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2901</th>
#       <td>squeeze de plastico personalizado</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2102</th>
#       <td>lacos</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>358</th>
#       <td>pote de vidro para lembrancinha</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3555</th>
#       <td>adesivo jateado para vidro</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3715</th>
#       <td>jogo de cozinha com 3 pecas</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1773</th>
#       <td>tapete cozinha</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>834</th>
#       <td>festa pokemon</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2216</th>
#       <td>bloco de anotacoes</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2361</th>
#       <td>placas</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>968</th>
#       <td>presente para avos</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4308</th>
#       <td>cachepot de madeira</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2840</th>
#       <td>cortina corta luz blackout blecaute 2 80x2 30 castor</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1692</th>
#       <td>mobile de berco</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2601</th>
#       <td>dentista</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2721</th>
#       <td>kit berco rolinho</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2265</th>
#       <td>pintura a oleo</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>761</th>
#       <td>bolo do flamengo</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>607</th>
#       <td>fraldinha de eva</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1629</th>
#       <td>artesanato com madeira</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2055</th>
#       <td>chaveiros dia dos pais</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1382</th>
#       <td>camiseta pai e filha</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4423</th>
#       <td>babador bandana</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1223</th>
#       <td>presente para o primeiro dia dos pais</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>766</th>
#       <td>gravata</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>kit mesa de festa</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4384</th>
#       <td>minions</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2274</th>
#       <td>flores de papel para decoracao</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>374</th>
#       <td>chinelos personalizados</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3073</th>
#       <td>porta maternidade amigurumi</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2784</th>
#       <td>convites realeza</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>placa homenagem</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1746</th>
#       <td>kit berco menino</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3352</th>
#       <td>mini caixote</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3852</th>
#       <td>enfeite de mesa princesa sofia</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2672</th>
#       <td>cha revelacao</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2422</th>
#       <td>pergolado</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1704</th>
#       <td>necesser personalizada</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4180</th>
#       <td>tag maternidade</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>482</th>
#       <td>estante organizadora de brinquedos</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1277</th>
#       <td>garrafinhas personalizadas</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>233</th>
#       <td>decoracao batizado</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1965</th>
#       <td>garrafa personalizada</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>871</th>
#       <td>presente dia dos pais para o sogro</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1897</th>
#       <td>dia dos namorados</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2875</th>
#       <td>vasos decorativos para sala</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3440</th>
#       <td>cortador de eva</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1845</th>
#       <td>turma do mickey</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1723</th>
#       <td>lacos pet</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4256</th>
#       <td>lembranca</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>98</th>
#       <td>feltro estampado</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Features (10 de 316)</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thea
