# %% [markdown]
# # Histórico e Análise de Experimentos de Classificação de Intenções de Busca
#
# Este *notebook* tem como objetivo permitir o registro visual dos experimentos feitos e oferecer um modo de recuperar um experimento e analisar os resultados em mais detalhes.

# %% [markdown]
# ## Bibliotecas e Funções

# %%
# General
import sys
import funcy as fp
from pathlib import Path

# Visualization / Presentation
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import HTML, display

import mlflow
from mlflow.tracking import MlflowClient
import pandas as pd

# Carregar, além de atualizar frequentemente, código personalizado disponível em ../src
# %load_ext autoreload 
# %autoreload 2
sys.path.append(str(Path.cwd().parent))
from src import settings
from src.utils.notebooks import display_side_by_side
from src.pipeline.inference_pipeline import load_model_resources

# Configurações para a exibição de conteúdo do Pandas e das bibliotecas gráficas
# %matplotlib inline 
sns.set(rc={'figure.figsize':(25,10)})
pd.set_option('display.max_rows', None)
pd.set_option("display.max_columns", None)
pd.set_option('max_colwidth', 150)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Recuperação do melhor resultado
#
# Considerando os experimentos feitos no notebook [Classificação de Intenções](04.3_Classificacao_de_Intencoes.ipynb), faz-se a recuperação dos melhores resultados de cada algoritmo, tendo como métrica principal o F1.

# %%
EXPERIMENT_ID = '2'

mlflow_client = MlflowClient()

best_experiments_result = [
    mlflow.search_runs(experiment_ids=[experiment_id], 
                       max_results=100, 
                       order_by=['metrics.F1 DESC'], 
                       filter_string='attributes.status="FINISHED"')
    for experiment_id in [EXPERIMENT_ID]
]

best_results = pd.concat(best_experiments_result, axis=0)

# %% [markdown]
# O melhores resultados recuperados:

# %%
columns_to_show = ['experiment_name', 'tags.mlflow.runName', 'run_id', 'experiment_id', 'params.model_name',
                   'metrics.f1', 'metrics.precision', 'metrics.recall', 'metrics.auc', 'metrics.mc', 'metrics.training_time']

(best_results
 .assign(experiment_name=lambda f: f['experiment_id'].apply(lambda id: mlflow_client.get_experiment(id).name))
 .sort_values(by='metrics.f1', ascending=False)
 .loc[lambda f: ~f['params.model_name'].isna()]
 .drop_duplicates('params.model_name')
 [columns_to_show]  
 .head()
)
# Out:
#                            experiment_name  \
# 62  04_SupervisedQueryIntentClassification
# 45  04_SupervisedQueryIntentClassification
# 48  04_SupervisedQueryIntentClassification
# 67  04_SupervisedQueryIntentClassification
# 15  04_SupervisedQueryIntentClassification
#
#                                    tags.mlflow.runName  \
# 62          01_2_More Restrictive Qualified Queries_CB
# 45  01_4_More Restrictive Qualified Queries_SVC-Linear
# 48         01_3_More Restrictive Qualified Queries_LGB
# 67  01_1_More Restrictive Qualified Queries_GaussianNB
# 15         01_8_More Restrictive Qualified Queries_MLP
#
#                               run_id experiment_id params.model_name  \
# 62  726952678b9f4cb2949b9707fa66a273             2                CB
# 45  77c9f07b95f84557b0d5899f9fd78568             2        SVC-Linear
# 48  c9a698923c6d40719b1353fb99a027a6             2               LGB
# 67  c342ae09559c4205b024da1f3fb63730             2        GaussianNB
# 15  19d377dfc5e94afaaa95a169d4e6db71             2               MLP
#
#     metrics.f1  metrics.precision  metrics.recall  metrics.auc  metrics.mc  \
# 62    0.666667           0.674419        0.659091     0.730489    0.463042
# 45    0.645914           0.664000        0.628788     0.714868    0.434457
# 48    0.644628           0.709091        0.590909     0.719625    0.457895
# 67    0.631579           0.534031        0.772727     0.676458    0.345353
# 15    0.626415           0.624060        0.628788     0.695911    0.391274
#
#     metrics.training_time
# 62               3.278462
# 45               2.549131
# 48               2.290449
# 67               0.003971
# 15               1.485022

# %% [markdown]
# ## Restauração de Experimentos
#
# A partir da escolha de uma execução individual, é possível restaurar os elementos utilizados na experimentação para aplicá-los aos dados.

# %%
RUN_ID = '11bed0968e80465f8775b94e95accffc'

preprocessing_model, model, label_encoder = load_model_resources(RUN_ID)

# %% [markdown]
# Para validar o funcionamento da restauração do modelo, parte dos dados de treinamento são recuperados para uma avaliação.

# %%
columns_to_read = ['query', 'intent_class', 'intent_description']

frame = pd.read_csv(Path(settings.DATA_PATH).joinpath('interim', 'query_intent_training.csv'), usecols=columns_to_read)

display_side_by_side([frame.head(10)], ['Conjunto de Dados de Intenções de Busca'])
# Out:
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Conjunto de Dados de Intenções de Busca</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#       <th>intent_class</th>
#       <th>intent_description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>super mario</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>estojo personalizado</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>girassol</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>difusor lembrancinha</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>festa borboleta</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>lapis personalizados</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>tag para lembrancinha de maternidade</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>kit jardinagem</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>newborn</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>kit bebe</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Tendo os dados, é possível refazer a preparação e fazer a predição da intenção de busca de cada elemento.

# %%
frame_slice = frame.sample(50)

# Processa os dados para inferência
features = preprocessing_model.predict(frame_slice)

# Realiza a inferência
frame_slice['pred'] = model.predict(features)

display_side_by_side([frame_slice, 
                      pd.DataFrame(features).describe().T.head(10)], 
                     ['Dados Recuperados e Predição', 
                      f'Features (10 de {features.shape[1]})'])

del frame_slice
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Dados Recuperados e Predição</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#       <th>intent_class</th>
#       <th>intent_description</th>
#       <th>pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>650</th>
#       <td>kit quadros</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>840</th>
#       <td>kit higiene porcelana</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>813</th>
#       <td>caneca de acrilico personalizada</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>391</th>
#       <td>tapete quarto</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>397</th>
#       <td>lembrancas de aniversario de 60 anos</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1443</th>
#       <td>papel de parede de amor</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1923</th>
#       <td>ladybug</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2065</th>
#       <td>lembrancinhas para aniversario de 80 anos</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1790</th>
#       <td>pintura de paisagem</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>969</th>
#       <td>decoracao de esmalteria</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>90</th>
#       <td>cardapio</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1648</th>
#       <td>jogo de banheiro de croche 4 pecas</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>167</th>
#       <td>bico de pato</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1553</th>
#       <td>bolsas de maternidade</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1554</th>
#       <td>lembrancinha poderoso chefinho</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1276</th>
#       <td>garrafas decoradas</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1549</th>
#       <td>petalas</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>201</th>
#       <td>jogo de banheiro rendado</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>487</th>
#       <td>kit lavabo</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1154</th>
#       <td>festa toy story</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>moldura</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2028</th>
#       <td>paisagens para fundo de igreja</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>758</th>
#       <td>caneca de aluminio</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1177</th>
#       <td>lembrancinha flamingo</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1632</th>
#       <td>saquinhos para maternidade</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>302</th>
#       <td>papel de parede personalizado com foto</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1610</th>
#       <td>lembrancinha masculina</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>433</th>
#       <td>convite cha de bebe</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>339</th>
#       <td>lembrancinhas de toalha de mao</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1547</th>
#       <td>brindes personalizados</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1026</th>
#       <td>presente formatura</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1555</th>
#       <td>centro de mesa cha de bebe</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1002</th>
#       <td>casamento</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1038</th>
#       <td>copo personalizado</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>624</th>
#       <td>manta trico</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2026</th>
#       <td>enfeite de porta maternidade</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>550</th>
#       <td>presente para afilhado de batismo</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>313</th>
#       <td>lembrancinha show da luna</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1921</th>
#       <td>manta</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>757</th>
#       <td>formatura medicina</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1850</th>
#       <td>lembrancinhas dia do estudante ponteiras</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>990</th>
#       <td>galinha pintadinha</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1299</th>
#       <td>mapa das estrelas</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1499</th>
#       <td>terco</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>820</th>
#       <td>papel de parede menina</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1544</th>
#       <td>lembrancinhas para padrinhos</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1517</th>
#       <td>lousa</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1806</th>
#       <td>bodas de perola lembrancinhas</td>
#       <td>0</td>
#       <td>Busca Exploratória</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>362</th>
#       <td>bloquinho personalizado dia dos pais</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1159</th>
#       <td>passadeira de croche para cozinha</td>
#       <td>1</td>
#       <td>Busca Focada</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Features (10 de 316)</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%<
