# %% [markdown]
# # Introdução
#
# O objetivo deste *notebook* é explorar os dados fornecidos pelo Elo7 para trabalhar com os problemas de classificação de produtos em categorias (supervisionado) e classificação da intenção dos usuários a partir dos termos de busca (não supervisionado). Conforme a [descrição do case](https://github.com/SamaraAlves/teste_HT):
#
# > O dataset escolhido para esse teste é composto de uma amostra de dados do Elo7. Você pode obter o dataset através desse link (se tiver problemas para obter os dados, por favor, nos avise que ajudaremos você).
# >
# > Em resumo, o dataset contém 38.507 registros distribuídos em 5 categorias (`Bebê`, `Bijuterias e Jóias`, `Decoração`, `Lembrancinhas`, `Papel e Cia` e `Outros`). Cada registro corresponde a um clique em um produto a partir de um termo de busca no site.
# >
# > Nesse dataset você encontrará as seguintes colunas:
# >
# > - **product_id** - identificação de produto
# > - **seller_id** - identificação do vendedor
# > - **query** - termo de busca inserido pelo usuário
# > - **search_page** - número da página que o produto apareceu nos resultados de busca (mín 1 e máx 5)
# > - **position** - número da posição que o produto apareceu dentro da página de busca (mín 0 e máx 38)
# > - **title** - título do produto
# > - **concatenated_tags** - tags do produto inseridas pelo vendedor (as tags estão concatenadas por espaço)
# > - **creation_date** - data de criação do produto na plataforma do Elo7
# > - **price** - preço do produto em reais
# > - **weight** - peso em gramas da unidade do produto reportado pelo vendedor
# > - **express_delivery** - indica se o produto é pronta entrega (1) ou não (0)
# > - **minimum_quantity** - quantidade de unidades mínima necessária para compra
# > - **view_counts** - número de cliques no produto nos últimos três meses
# > - **order_counts** - número de vezes que o produto foi comprado nos últimos três meses
# > - **category** - categoria do produto
#
#
# É possível entender melhor a origem e o significado dos dados a partir da página de [busca do Elo7](https://www.elo7.com.br/). Na tela inicial, o usuário pode visualizar categorias de produtos, o campo de busca e alguns produtos disponíveis.
#
# ![Image](./assets/tela_inicial_busca_formatada.png)
#
# Ao submeter termos de busca, o usuário é levado à página de resultados.
#
#
# ![Image](./assets/tela_resultados_busca_formatada.png)
#
# Pela imagens de busca, é possível notar que o número máximo de páginas de resultados pode exceder o limite de 5 presente nos dados. Além disso, os critérios de ordenação podem influenciar a posição de cada produto na página para um mesmo resultado de busca.
#
# Caso o usuário clique em um produto, a tela de apresentação é exibida.
#
# ![Image](./assets/tela_apresentacao_produto_formatada.png)
#
# É possível ver que categorias têm uma construção hierárquica, apesar de os dados terem apenas o último nível. Além disso, o número de tags pode ser bem variado, o que pode ser melhor caracterizado ao analisar os dados.
#
# A presença de um sistema de avaliação dos vendedores mostra que a reputação do vendedor pode ser um fator de influência nos cliques e vendas.

# %% [markdown]
# # Bibliotecas e Funções

# %%
# Usado para ler arquivos, carregar código personalizado e ter acesso a outros recursos de sistema
import sys
from pathlib import Path

# Recursos para texto
import re

# Verificação de tipos
from typing import List, Callable

# Manipulação e análise dos dados
import numpy as np
import pandas as pd
import missingno as msno

# Recursos para visualização dos dados
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import HTML, display

# Carregar código personalizado disponível em ../src
#sys.path.append(os.path.abspath(os.path.pardir))
sys.path.append(str(Path.cwd().parent))
from src import settings
from src.utils.notebooks import display_side_by_side
from src.utils.experiments import set_dataset_split, extract_tokens

# Configurações para a exibição de conteúdo do Pandas e das bibliotecas gráficas
# %matplotlib inline 
sns.set(rc={'figure.figsize':(25,10)})
pd.set_option('display.max_rows', None)
pd.set_option("display.max_columns", None)
pd.set_option('max_colwidth', 150)

# %% [markdown]
# # Resumo
#
# Este resumo, em processo de desenvolvimento, lista os principais achados e preocupações que devem ser considerados durante a criação dos modelos supervisionados e não supervisionados:
#  - Pela natureza do projeto, que envolve a criação frequente de novos produtos e tem diferentes padrões de descrição por parte dos usuários, sejam eles vendedores ou compradores, é preciso ter a preocupação com valores textuais novos relacionados a títulos, *tags* e consultas.
#  - Há valores não preenchidos na coluna de contagem de pedido.
#  - A concatenação das *tags* parece provocar uma perda, ao fazer a decomposição dos elementos, com relação às expressões compostas que formariam uma *tag* única.
#  - Em geral, se um produto tem mais de uma ocorrência é de se esperar que exista a variação em algum dos atributos não relacionados à interações e busca: preço, peso, pronta entrega e quantidade mínima.
#  - As *tags* já são pre-processadas e normalizadas. Isso deve reduzir o esforço de tratamento dos dados, mas pode ter um impacto em algumas formas de se trabalhar com o texto, pela não correspondência entre as palavras que teriam acentuação.
#  - Há um grande desbalanceamento de categorias, que tende a manter a mesma ordem de categorias mais frequentes ao longo do tempo, então é preciso fazer algum tratamento na criação do modelo (provavelmente usar balanceamento por peso ou amostragem). Como a única referência de tempo diz respeito à data de criação, é provável que o aumento da quantidade de registros ao longo do tempo esteja relacionado não apenas ao crescimento do Elo7, mas também à "sobrevivência" dos produtos no mercado ao longo do tempo (quanto mais tempo um produto tem, maior a chance de ele ser substituído ou descontinuado por outro fator).
#
# # Ideias para o Projeto
#
# A partir do estudo realizado, pode-se identificar algumas possibilidades de melhorias neste *notebook* ou em etapas futuras do projeto. Algumas são inviáveis com os dados presentes, mas podem ser exploradas com acesso aos dados completos.
#
# ## Com potencial de exploração
#  - Transformação dos dados e engenharia de características:
#      - Criar proporção entre visualizações e pedidos -- produtos com número de pedidos próximo ou maior do que o de visualizações podem indicar uma taxa interessante de sucesso;
#      - Descartar *tags* poucos significativas em produtos com número grande de *tags*
#          - Usar *n* primeiras *tags*;
#          - Criar "*tags* qualificadas" verificando quais ocorrem no título ou na busca;
#          - Filtrar com base na própria noção de relevância por TF-IDF ou BM25.
#  - Aumentação de dados para texto:
#      - Fazer tradução e retradução de texto para obter variações das mesmas consultas;
#      - Usar ontologia/tesauro/*embeddings* para obter palavras ou tags semelhantes;
#
#  - Fazer *fine tune* de modelo (e.g., BERT ou Word2Vec) com base na busca. Como todos os registros são de cliques, que indicam casos positivos, poderiam ser criados exemplos negativos usando produtos que não têm interseção com termos de busca, *tag* e título. Tanto o modelo em si, quanto os *embeddings* poderiam ser usados.
#  - TF-IDF pode ser alternativa simples e eficaz considerando que as palavras já são em grande parte normalizadas. No entanto, é preciso ter em mente palavras fora do vocabulário.
#
#
# # Sem potencial ou inviáveis
#  - Criar noção de tendência de interesse: pela falta da data de realização da consulta, não é possível determinar se há aumento ou redução de interesse em uma janela de tempo;
#  - Identificar o nicho dos vendedores: é provável que existam vendedores com grande variedade de produtos, porém, també é possível que existam alguns com uma linha de atuação mais específica, que tenham produtos sempre em uma mesma categoria. Fazer um estudo nesse sentido pode ter uma contribuição na classificação de categorias. Por exemplo, um produto recém criado pode ter o conteúdo um pouco vago ou ambíguo, mas o vendedor tem portifólio de produtos bastante heterogêneo já classificado. Nesse caso, é possível usar essa informação como influência para que o produto seja mantido na mesma linha que os demais produtos ofertados.

# %% [markdown]
# # Análise Exploratória
#
# A exploração dos dados será feita a partir do conjunto de treinamento gerado no notebook [01_Estruturacao.ipynb](01_Estruturacao.ipynb). Com isso, os dados de treinamento ficam isolados e podem ser utilizados para fazer uma avaliação da eficácia dos modelos em dados novos, como ocorreria em produção.

# %%
frame = pd.read_csv(str(Path(settings.DATA_PATH).joinpath('interim', 'training.csv')))

# %%
print(f'Registros: {len(frame)}.')

frame.head(10)
# Out:
# Registros: 32746.
#    product_id  seller_id                                query  search_page  \
# 0    11394449    8324141                       espirito santo            2
# 1    15534262    6939286                     cartao de visita            2
# 2    15877252    8071206  medidas lencol para berco americano            1
# 3    15917108    7200773                 adesivo box banheiro            3
# 4     4336889    3436479                         dia dos pais            1
# 5     7544556    7118324          arranjo de flores para mesa            1
# 6    10869150    5203458             lembrancinha maternidade            5
# 7    13193769    2933585                chaveiro dia dos pais            1
# 8    13424151    8530613                  manta personalizada            1
# 9    12595651    5371868                                 pais            1
#
#    position                                                 title  \
# 0         6                                Mandala Espírito Santo
# 1         0                                      Cartão de Visita
# 2         6                        Jogo de Lençol Berço Estampado
# 3        38                               ADESIVO BOX DE BANHEIRO
# 4        37                      Álbum de figurinhas dia dos pais
# 5         9                         Arranjo de Flores - Orquidias
# 6        18  Kit Aromarizador + sacola / Lembrancinha Maternidade
# 7        35                                 chaveiro dia dos pais
# 8        20       Manta para bebê personalizada de Nuvem com nome
# 9        28                                  Chinelo Dia dos Pais
#
#                                                                                 concatenated_tags  \
# 0                                                                                     mandala mdf
# 1                                   cartao visita panfletos tag adesivos copos long drink canecas
# 2                                                               t jogo lencol menino lencol berco
# 3                                                                            adesivo box banheiro
# 4                                                         albuns figurinhas pai lucas album fotos
# 5                                                                                   mini arranjos
# 6  bb lembrancinhas maternidade baby lembranca maternidade bebe conforto lembrancinha maternidade
# 7                                                                                        dia pais
# 8                                                     nascimento manta baby cha bebe vestido bebe
# 9                                                                               sandalia dia pais
#
#          creation_date       price  weight  express_delivery  \
# 0  2015-11-14 19:42:12  171.890000  1200.0                 1
# 1  2018-04-04 20:55:07   77.670000     8.0                 1
# 2  2017-02-27 13:26:03  118.770004     0.0                 1
# 3  2017-05-09 13:18:38  191.810000   507.0                 1
# 4  2018-07-11 10:41:33   49.970000   208.0                 1
# 5  2016-04-22 13:34:16   23.670000   207.0                 1
# 6  2017-10-05 00:26:02   12.710000    55.0                 0
# 7  2018-07-04 12:47:49   11.420000     6.0                 1
# 8  2018-04-03 16:10:51  107.100000     9.0                 1
# 9  2018-06-25 23:23:14   17.390000     6.0                 1
#
#    minimum_quantity  view_counts  order_counts       category   period
# 0                 4          244           NaN      Decoração  2015-11
# 1                 5          124           NaN    Papel e Cia  2018-04
# 2                 1          180           1.0           Bebê  2017-02
# 3                 6           34           NaN      Decoração  2017-05
# 4                 1         1093           NaN  Lembrancinhas  2018-07
# 5                 5          276           NaN      Decoração  2016-04
# 6                33         1178         109.0  Lembrancinhas  2017-10
# 7                23           72           NaN  Lembrancinhas  2018-07
# 8                 1          639          26.0           Bebê  2018-04
# 9                22          933           NaN  Lembrancinhas  2018-06

# %% [markdown]
# ## Transformação dos Tipos de Dados
#
# Para permitir que cada elemento do conjunto de dados seja analisado adequadamente, os tipos das colunas serão transformados.

# %%
frame = pd.read_csv(str(Path(settings.DATA_PATH).joinpath(settings.DATA_PATH, 'interim', 'training.csv')))

# Mapeamento de colunas e tipos que devem ser atribuídos
columns_types = {'product_id': 'category',
                 'seller_id': 'category',
                 'query': 'string',
                 'search_page': 'int64',
                 'position': 'int64',
                 'title': 'string',
                 'concatenated_tags': 'string',
                 'creation_date': 'datetime64',
                 'price': 'float64',
                 'weight': 'float64',
                 'express_delivery': 'bool',
                 'minimum_quantity': 'int64',
                 'view_counts': 'int64',
                 'order_counts': 'float64',
                 'category': 'category',
                 'period': 'category'
                }

# Manter tipos originais
original_types_frame = pd.DataFrame(frame.dtypes, columns=['Original'])

# Converter tipos e mapear os novos
frame = frame.astype(columns_types)
types_frame = pd.concat([original_types_frame, 
                         pd.DataFrame(frame.dtypes, columns=['Transformado'])], axis=1)

# Mostrar resultados
display_side_by_side([types_frame], ['Comparação entre Tipos Originais e Novos'])

del original_types_frame, types_frame
# Out:
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Comparação entre Tipos Originais e Novos</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Original</th>
#       <th>Transformado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>product_id</th>
#       <td>int64</td>
#       <td>category</td>
#     </tr>
#     <tr>
#       <th>seller_id</th>
#       <td>int64</td>
#       <td>category</td>
#     </tr>
#     <tr>
#       <th>query</th>
#       <td>object</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>search_page</th>
#       <td>int64</td>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>position</th>
#       <td>int64</td>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>title</th>
#       <td>object</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>concatenated_tags</th>
#       <td>object</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>creation_date</th>
#       <td>object</td>
#       <td>datetime64[ns]</td>
#     </tr>
#     <tr>
#       <th>price</th>
#       <td>float64</td>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>weight</th>
#       <td>float64</td>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>express_delivery</th>
#       <td>int64</td>
#       <td>bool</td>
#     </tr>
#     <tr>
#       <th>minimum_quantity</th>
#       <td>int64</td>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>view_counts</th>
#       <td>int64</td>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>order_counts</th>
#       <td>float64</td>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>category</th>
#       <td>object</td>
#       <td>category</td>
#     </tr>
#     <tr>
#       <th>period</th>
#       <td>object</td>
#       <td>category</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# ## Sumarização dos Valores das Colunas
#
# Com os tipos transformados, é possível obter uma visão geral do comportamento dos dados de acordo com sua natureza (numérica ou categórica). Uma visão semelhante tinha sido obtida no [primeiro notebook](01_Estruturacao.ipynb), mas ela foi feita apenas para um produto, evitando a utilização de dados do conjunto de teste.

# %%
# Mapear tipos de colunas e separá-las
categorical_types = set(['category', 'string', 'bool'])
categorical_columns = [key for key, value in columns_types.items() if value in categorical_types]
numeric_columns = [key for key, value in columns_types.items() if value not in categorical_types]

# Mostrar descrição das colunas por tipo de dados
display_side_by_side([frame[numeric_columns].describe(include='all', datetime_is_numeric=True),
                     frame[categorical_columns].describe(include='all')],
                     ['Colunas Numéricas', 'Colunas Categóricas'])

del columns_types, categorical_types, categorical_columns, numeric_columns
# Out:
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Colunas Numéricas</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>search_page</th>
#       <th>position</th>
#       <th>creation_date</th>
#       <th>price</th>
#       <th>weight</th>
#       <th>minimum_quantity</th>
#       <th>view_counts</th>
#       <th>order_counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>32746.000000</td>
#       <td>32746.000000</td>
#       <td>32746</td>
#       <td>32746.000000</td>
#       <td>32688.000000</td>
#       <td>32746.000000</td>
#       <td>32746.000000</td>
#       <td>15736.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>1.497557</td>
#       <td>16.733006</td>
#       <td>2017-04-23 04:49:03.134795264</td>
#       <td>83.253023</td>
#       <td>344.624572</td>
#       <td>15.089385</td>
#       <td>565.709369</td>
#       <td>27.598246</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>2008-11-05 22:57:17</td>
#       <td>0.080000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>1.000000</td>
#       <td>6.000000</td>
#       <td>2016-10-26 02:27:43.500000</td>
#       <td>12.690000</td>
#       <td>6.000000</td>
#       <td>3.000000</td>
#       <td>130.000000</td>
#       <td>8.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1.000000</td>
#       <td>16.000000</td>
#       <td>2017-09-03 15:24:02</td>
#       <td>27.805000</td>
#       <td>9.000000</td>
#       <td>7.000000</td>
#       <td>259.000000</td>
#       <td>15.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>2.000000</td>
#       <td>27.000000</td>
#       <td>2018-04-09 17:28:10.500000</td>
#       <td>91.800000</td>
#       <td>106.000000</td>
#       <td>17.000000</td>
#       <td>546.000000</td>
#       <td>26.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>5.000000</td>
#       <td>38.000000</td>
#       <td>2018-08-31 23:53:12</td>
#       <td>6289.420000</td>
#       <td>65009.000000</td>
#       <td>3000.000000</td>
#       <td>34061.000000</td>
#       <td>2460.000000</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.985655</td>
#       <td>11.598638</td>
#       <td>NaN</td>
#       <td>200.388410</td>
#       <td>1705.857187</td>
#       <td>46.206338</td>
#       <td>1365.994604</td>
#       <td>61.397492</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Colunas Categóricas</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>seller_id</th>
#       <th>query</th>
#       <th>title</th>
#       <th>concatenated_tags</th>
#       <th>express_delivery</th>
#       <th>category</th>
#       <th>period</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>32746</td>
#       <td>32746</td>
#       <td>32746</td>
#       <td>32746</td>
#       <td>32744</td>
#       <td>32746</td>
#       <td>32746</td>
#       <td>32746</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>25156</td>
#       <td>7398</td>
#       <td>5949</td>
#       <td>21509</td>
#       <td>20254</td>
#       <td>2</td>
#       <td>6</td>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>7557702</td>
#       <td>1433098</td>
#       <td>bolsa maternidade</td>
#       <td>Lembrancinha Batizado</td>
#       <td>dia pais</td>
#       <td>True</td>
#       <td>Lembrancinhas</td>
#       <td>2018-07</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>14</td>
#       <td>240</td>
#       <td>139</td>
#       <td>64</td>
#       <td>408</td>
#       <td>25737</td>
#       <td>15085</td>
#       <td>2088</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Algumas observações que podem ser feitas sobre a visão descritiva dos valores numéricos:
#  - **Até 75%** dos cliques de produtos ocorreram **até a 2ª página** dos resultados de busca, sendo que o maior número de páginas dessa amostra é 5.
#  - **Até 50%** dos cliques ocorrem até **a posição 16 da página**. Enquanto o valor máximo de posição nos dados é 38, a página atual de resultados de busca do Elo7 exibe 40 itens. Esse resultado pode indicar que parte considerável dos usuários não chega ao fim da página para acessar uma outra página de resultado, conforme o item anterior.
#  - Os **produtos** disponíveis foram **criados em um período de até 10 anos**. Pelo fato de a metade dos registros abranger o período de 2008 a 2017 e a segunda metade considerar 2017 e 2018, é possível entender que **há mais dados sobre produtos mais recentes**, o que pode estar relacionado a um número de cliques maior a produtos mais recentes ou a uma quantidade maior de produtos recentes.
#  - A variação de pesos vai de 15 g a 65 kg, com a **predominância de produtos leves**, de até 106g. Provavelmente móveis e produtos mais pesados estão influenciando a média e o desvio padrão.
#  - A quantidade mínima pode chegar a 3.000 itens, mas **até 75% dos registros possuem a quantidade mínima de até 17**.
#  - A **contagem de visualizações**, que considera a janela de 3 meses, possui **valores acima de 100 já para os primeiros 25% dos registros**. Mesmo com essa janela, há produtos bastante propulares, com mais de 30.000 visualizações.
#  - A **contagem de pedidos** tem **valor mínimo de 1**. É preciso verificar se a ausência de pedidos não está sendo identificada como um valor não preenchido.
#
#
# Sobre os valores categóricos:
#  - Grande parte dos produtos têm apenas uma ocorrência (**~77% dos registros são de produtos únicos**);
#  - Há maior repetição de vendedores. São cerca de **4 registros por vendedor**.
#  - Há considerável repetição de consultas. São cerca de **6 registros por consulta**.
#  - Os **títulos de produtos são mais diversos**, sendo 65% únicos (o número equivale ao de *product_ids* únicos).
#  - A combinação de todas as *tags* tem diversidade semelhante à de títulos, mas uma análise por *tags* individuais deve ser mais adequada.
#  - Produtos à **pronta entrega** são mais frequentes, com quase **80% dos casos**.
#  - Das 6 categorias, **'Lembracinhas' é a mais fequente**, com cerca de 46% dos casos.
#  - Da combinação de ano e mês, **Julho de 2018** é a que tem maior quantidade de registros, com **6% do total**. São 115 combinações de ano e mês.

# %% [markdown]
# ## Análise de Valores Ausentes
#
# Para complementar a visão dos dados, é importante verificar se há valores não preenchidos. Uma primeira visão é ter a noção de quais colunas apresentam algum valor ausente e em qual frequência isso ocorre.

# %%
msno.matrix(frame)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Conforme a imagem apresenta, as colunas **weight** e **order_counts** possuem valores vazios. Enquanto a primeira possui apenas uma ocorrência, que pode ser descartada ou tratada, a segunda possui uma quantidade maior.
#
# Como se trata de uma base de dados bem controlada, parece improvável que a ausência de valores ocorra por algum erro ou má qualidade dos dados. Uma hipótese é a de que produtos sem pedidos nos últimos 3 meses estejam sendo representados com valor ausente em vez de valor 0.

# %%
# Gerar agregação com o total de registros e a contabilização de quantos não foram preenchidos
missing_order_counts_frame = (
    frame
    [['product_id', 'order_counts']]
    .assign(is_missing=lambda f: f['order_counts'].isna())
    .assign(registros=1)
    .groupby('product_id')
    .sum()
    .reset_index()
    .assign(diferenca=lambda f: f['registros'] - f['is_missing'])
    .sort_values(by=['is_missing', 'registros'], ascending=[False, False])
)

display_side_by_side([missing_order_counts_frame.head(15),
                      (missing_order_counts_frame
                       .loc[lambda f: f['is_missing'] > 0]
                       .sort_values(by=['diferenca', 'registros'], ascending=[False, False])
                       .head(15))
                     ],
                     ['Produtos com Maior Frequência de Valores Ausentes',
                      'Produtos Com alguns Valores Ausentes'],
                    padding=100)
# Out:
#                       <div style='display:block;float:left;padding:0 100px 0 0;text-align:center'>
#                          <h3>Produtos com Maior Frequência de Valores Ausentes</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>order_counts</th>
#       <th>is_missing</th>
#       <th>registros</th>
#       <th>diferenca</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>16700</th>
#       <td>11130723</td>
#       <td>0.0</td>
#       <td>12</td>
#       <td>12</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>21351</th>
#       <td>14155651</td>
#       <td>0.0</td>
#       <td>11</td>
#       <td>11</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8062</th>
#       <td>5395219</td>
#       <td>0.0</td>
#       <td>10</td>
#       <td>10</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11583</th>
#       <td>7747109</td>
#       <td>0.0</td>
#       <td>10</td>
#       <td>10</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6514</th>
#       <td>4336889</td>
#       <td>0.0</td>
#       <td>9</td>
#       <td>9</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10369</th>
#       <td>6916970</td>
#       <td>0.0</td>
#       <td>9</td>
#       <td>9</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10434</th>
#       <td>6960600</td>
#       <td>0.0</td>
#       <td>9</td>
#       <td>9</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13814</th>
#       <td>9180973</td>
#       <td>0.0</td>
#       <td>9</td>
#       <td>9</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>934</th>
#       <td>599278</td>
#       <td>5.0</td>
#       <td>7</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18557</th>
#       <td>12350793</td>
#       <td>12.0</td>
#       <td>7</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2419</th>
#       <td>1608960</td>
#       <td>0.0</td>
#       <td>7</td>
#       <td>7</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4848</th>
#       <td>3163452</td>
#       <td>0.0</td>
#       <td>7</td>
#       <td>7</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6250</th>
#       <td>4155595</td>
#       <td>0.0</td>
#       <td>7</td>
#       <td>7</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>12954</th>
#       <td>8633358</td>
#       <td>0.0</td>
#       <td>7</td>
#       <td>7</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>19046</th>
#       <td>12647246</td>
#       <td>0.0</td>
#       <td>7</td>
#       <td>7</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 100px 0 0;text-align:center'>
#                          <h3>Produtos Com alguns Valores Ausentes</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>order_counts</th>
#       <th>is_missing</th>
#       <th>registros</th>
#       <th>diferenca</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>17403</th>
#       <td>11596456</td>
#       <td>40.0</td>
#       <td>6</td>
#       <td>8</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>562</th>
#       <td>384860</td>
#       <td>39.0</td>
#       <td>5</td>
#       <td>7</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1819</th>
#       <td>1217193</td>
#       <td>24.0</td>
#       <td>4</td>
#       <td>6</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>8874</th>
#       <td>5940345</td>
#       <td>28.0</td>
#       <td>3</td>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>12176</th>
#       <td>8121882</td>
#       <td>19.0</td>
#       <td>3</td>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>379</th>
#       <td>258648</td>
#       <td>23.0</td>
#       <td>2</td>
#       <td>4</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4398</th>
#       <td>2893083</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7401</th>
#       <td>4947049</td>
#       <td>16.0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>9989</th>
#       <td>6668372</td>
#       <td>19.0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>19702</th>
#       <td>13077505</td>
#       <td>13.0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>23698</th>
#       <td>15711225</td>
#       <td>41.0</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>934</th>
#       <td>599278</td>
#       <td>5.0</td>
#       <td>7</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18557</th>
#       <td>12350793</td>
#       <td>12.0</td>
#       <td>7</td>
#       <td>8</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2122</th>
#       <td>1417590</td>
#       <td>5.0</td>
#       <td>6</td>
#       <td>7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3561</th>
#       <td>2369348</td>
#       <td>14.0</td>
#       <td>5</td>
#       <td>6</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Como é possível observar, há produtos em que todos os registros têm o contador de pedidos nulo, enquanto há outros em que alguns registros estão nulos e outros não. Alguns desses casos com situações mistas de prenchimento serão visualizados.

# %%
# Dados os 3 IDs de produtos com mais valores ausentes, mostrar o histórico de registros
for product_id in [11596456, 384860, 1217193]:
    sub_frame = frame.loc[lambda f: f['product_id'] == product_id]
    display(HTML(f'<h4>{sub_frame["title"].iloc[0]}</h4>'))
    display(sub_frame.sort_values(by=['product_id', 'view_counts', 'order_counts']))
    
del sub_frame
# Out:
# <h4>lembrancinhas de casamento</h4>
#       product_id seller_id                         query  search_page  \
# 6081    11596456   2133131                 lembrancinhas            5
# 13013   11596456   2133131     lembrancinha de casamento            1
# 21990   11596456   2133131    lembrancinhas de casamento            1
# 21514   11596456   2133131   lembrancinha para casamento            1
# 10702   11596456   2133131                     casamento            2
# 19231   11596456   2133131                     casamento            2
# 24900   11596456   2133131        lembrancinha casamento            4
# 14526   11596456   2133131  lembrancinhas para casamento            1
#
#        position                       title  \
# 6081         33  lembrancinhas de casamento
# 13013        20  lembrancinhas de casamento
# 21990         6  lembrancinhas de casamento
# 21514         9  lembrancinhas de casamento
# 10702        27  lembrancinhas de casamento
# 19231        27  lembrancinhas de casamento
# 24900         5  lembrancinhas de casamento
# 14526         5  lembrancinhas de casamento
#
#                                                                            concatenated_tags  \
# 6081   lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
# 13013  lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
# 21990  lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
# 21514  lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
# 10702  lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
# 19231  lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
# 24900  lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
# 14526  lembranca casamento arquivos silhouette lembrancinha casamento casamento lembrancinha
#
#             creation_date  price  weight  express_delivery  minimum_quantity  \
# 6081  2016-01-04 15:24:06   1.97     7.0              True                 6
# 13013 2016-01-04 15:24:06  12.41     6.0              True                10
# 21990 2016-01-04 15:24:06  10.63     8.0              True                11
# 21514 2016-01-04 15:24:06   1.97     5.0              True                11
# 10702 2016-01-04 15:24:06  11.76     8.0              True                10
# 19231 2016-01-04 15:24:06  10.87     6.0              True                 6
# 24900 2016-01-04 15:24:06   1.97     0.0              True                12
# 14526 2016-01-04 15:24:06  10.90     9.0              True                 6
#
#        view_counts  order_counts       category   period
# 6081          2196          16.0  Lembrancinhas  2016-01
# 13013         2196           NaN  Lembrancinhas  2016-01
# 21990         2196           NaN  Lembrancinhas  2016-01
# 21514         2213           NaN  Lembrancinhas  2016-01
# 10702         2216           NaN  Lembrancinhas  2016-01
# 19231         2243          24.0  Lembrancinhas  2016-01
# 24900         2248           NaN  Lembrancinhas  2016-01
# 14526         2264           NaN  Lembrancinhas  2016-01
# <h4>Lembrancinha gravata chaveiro</h4>
#       product_id seller_id  \
# 1110      384860   7461314
# 12076     384860   7461314
# 23207     384860   7461314
# 25806     384860   7461314
# 5493      384860   7461314
# 29990     384860   7461314
# 16575     384860   7461314
#
#                                                     query  search_page  \
# 1110     lembrancinhas para o dia dos pais gravata de eva            1
# 12076                       lembrancinha dia dos pais eva            1
# 23207  lembrancinhas para o dia dos pais chaveiro gravata            1
# 25806                           lembrancinha dia dos pais            5
# 5493      lembrancinha de eva para dias dos pais fasiu de            1
# 29990                 chaveiro de eva para o dia dos pais            1
# 16575                           lembrancinha dia dos pais            5
#
#        position                          title  \
# 1110          0  Lembrancinha gravata chaveiro
# 12076        23  Lembrancinha gravata chaveiro
# 23207         1  Lembrancinha gravata chaveiro
# 25806        14  Lembrancinha gravata chaveiro
# 5493         28  Lembrancinha gravata chaveiro
# 29990        26  Lembrancinha gravata chaveiro
# 16575        14  Lembrancinha gravata chaveiro
#
#                                                  concatenated_tags  \
# 1110   tacas casamento dia pais religiosa chaveiro gravata gravata
# 12076  tacas casamento dia pais religiosa chaveiro gravata gravata
# 23207  tacas casamento dia pais religiosa chaveiro gravata gravata
# 25806  tacas casamento dia pais religiosa chaveiro gravata gravata
# 5493   tacas casamento dia pais religiosa chaveiro gravata gravata
# 29990  tacas casamento dia pais religiosa chaveiro gravata gravata
# 16575  tacas casamento dia pais religiosa chaveiro gravata gravata
#
#             creation_date  price  weight  express_delivery  minimum_quantity  \
# 1110  2016-03-02 21:42:21   9.92     8.0              True                29
# 12076 2016-03-02 21:42:21   9.47     5.0              True                29
# 23207 2016-03-02 21:42:21   0.59     6.0              True                25
# 25806 2016-03-02 21:42:21   0.59     6.0              True                32
# 5493  2016-03-02 21:42:21  11.10     6.0              True                28
# 29990 2016-03-02 21:42:21  10.71     8.0              True                25
# 16575 2016-03-02 21:42:21   9.94     6.0              True                36
#
#        view_counts  order_counts       category   period
# 1110           757          22.0  Lembrancinhas  2016-03
# 12076          757           NaN  Lembrancinhas  2016-03
# 23207          757           NaN  Lembrancinhas  2016-03
# 25806          757           NaN  Lembrancinhas  2016-03
# 5493           777           NaN  Lembrancinhas  2016-03
# 29990          785           NaN  Lembrancinhas  2016-03
# 16575          812          17.0  Lembrancinhas  2016-03
# <h4>forminha toy story</h4>
#       product_id seller_id        query  search_page  position  \
# 15488    1217193   4315729  toy story 4            1         6
# 5213     1217193   4315729    toy story            2         3
# 30841    1217193   4315729    toy story            2         3
# 15650    1217193   4315729    toy story            5        22
# 17733    1217193   4315729    toy story            5        22
# 16317    1217193   4315729    toy story            2         3
#
#                     title  \
# 15488  forminha toy story
# 5213   forminha toy story
# 30841  forminha toy story
# 15650  forminha toy story
# 17733  forminha toy story
# 16317  forminha toy story
#
#                                                                                          concatenated_tags  \
# 15488  caixinhas doce festa toy story aniversario toy story festa pedro niver toy story forminha 4 petalas
# 5213   caixinhas doce festa toy story aniversario toy story festa pedro niver toy story forminha 4 petalas
# 30841  caixinhas doce festa toy story aniversario toy story festa pedro niver toy story forminha 4 petalas
# 15650  caixinhas doce festa toy story aniversario toy story festa pedro niver toy story forminha 4 petalas
# 17733  caixinhas doce festa toy story aniversario toy story festa pedro niver toy story forminha 4 petalas
# 16317  caixinhas doce festa toy story aniversario toy story festa pedro niver toy story forminha 4 petalas
#
#             creation_date  price  weight  express_delivery  minimum_quantity  \
# 15488 2016-01-24 22:24:27  10.09     0.0              True               100
# 5213  2016-01-24 22:24:27  10.52     9.0             False               100
# 30841 2016-01-24 22:24:27   8.74     0.0              True               104
# 15650 2016-01-24 22:24:27   9.25     6.0              True               100
# 17733 2016-01-24 22:24:27   9.51     0.0             False               108
# 16317 2016-01-24 22:24:27   9.05     8.0              True               108
#
#        view_counts  order_counts       category   period
# 15488          431          18.0  Lembrancinhas  2016-01
# 5213           431           NaN  Lembrancinhas  2016-01
# 30841          431           NaN  Lembrancinhas  2016-01
# 15650          451           6.0  Lembrancinhas  2016-01
# 17733          466           NaN  Lembrancinhas  2016-01
# 16317          472           NaN  Lembrancinhas  2016-01

# %% [markdown]
# Ainda que não se possa garantir a consistência dessa visão, ordenar produtos pela quantidade de visualizações pode ser uma aproximação razoável da ordem cronológica de existência e acessos ao produto. Considerando isso, poderia se esperar que a quantidade de pedidos fosse relativamente próxima para outras ocorrências do mesmo produto que tivessem o mesmo total de visualizações. Isso, porém, não ocorre, conforme o produto *lembrancinhas de casamento*.
#
# É possível observar, com relação aos três produtos, que há variações de outros atributos mesmo quando a contagem de visualizações é a mesma. Isso pode tanto indicar uma diferença no tempo, quanto alguma regra de negócio que zera o total de pedidos com a mudança das características de um produto -- apesar de ser o mesmo produto à venda pelo mesmo vendedor.
#
# A seguir, tenta-se verificar se há alguma correlação que ajude a explicar a ocorrência de valores ausentes.

# %%
msno.heatmap(frame)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Pelo mapa de calor de correlações, não é possível determinar uma correlação alta. O elemento com maior correlação é peso, que realmente varia nos 3 casos analisados. Ainda assim, é uma correlação baixa.
#
# Para se lidar com os casos de valores ausentes, duas estratégias que podem ser seguidas na fase de desenvolvimento do modelo:
#  - Utilizar média ou mediana (com relação ao próprio produto, à sua categoria ou a produtos com características semelhantes) para fazer a imputação;
#  - Empregar algoritmos que permitam a utilização de valores ausentes.

# %% [markdown]
# ## Análise de Colunas
#
# Nesta seção serão analisadas em maior detalhe algumas colunas que podem representar entidades ou valores que podem ser determinantes neste estudo. Outras colunas, sobretudo com valor essencialmente numérico, podem ser mantidas apenas no nível de sumarização estatística, feita na seção [Sumarização dos Valores das Colunas](#Sumarização-dos-Valores-das-Colunas).
#
# ### Entendimento sobre Produtos
#
# Para entender os dados e como modelar melhor o problema, serão feitas algumas verificações com o intuito de entender:
#  - Um mesmo produto pode ser vendido por mais de um vendedor?
#  - O título de um produto se repete entre vendedores diferentes?
#  - Um produto pode apresentar *tags* diferentes?
#  - Produtos com títulos iguais podem apresentar *tags* diferentes?
#  - Desconsiderando atributos relacionados à busca ou às interações, quais atributos costumam variar para um mesmo produto ao longo do tempo?
#
# A seguir são feitas algumas agregações dos dados para viabilizar o entendimento das questões supracitadas.

# %%
def aggregate_by_columns(base_frame: pd.DataFrame, columns:List[str], group_columns:List[str], records: int=10) -> pd.DataFrame:
    """Função para repetir a agregação dos dados baseados em listas de colunas"""

    agg_frame = (
        base_frame
        [columns]
        .drop_duplicates()
        .assign(ocorrencias_unicas=1)
        .groupby(group_columns)
        .sum()
        .reset_index()
        .sort_values(by='ocorrencias_unicas', ascending=False)
        .head(records)
    )

    return agg_frame

display_side_by_side([aggregate_by_columns(frame, ['product_id', 'seller_id'], ['product_id']),
                      aggregate_by_columns(frame, ['title', 'seller_id'], ['title']),
                      aggregate_by_columns(frame, ['concatenated_tags', 'product_id'], ['product_id']),
                      aggregate_by_columns(frame, ['concatenated_tags', 'title'], ['title'])
                     ],
                     ['Vendedores por Produto',
                      'Vendedores por Títulos de Produto',
                      'Tags por Produto',
                      'Tags por Títulos de Produto'],
                     padding=50)
# Out:
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Vendedores por Produto</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>ocorrencias_unicas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>361</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16779</th>
#       <td>11197600</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16777</th>
#       <td>11196802</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16776</th>
#       <td>11196229</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16775</th>
#       <td>11193657</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16774</th>
#       <td>11193421</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16773</th>
#       <td>11193205</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16772</th>
#       <td>11192919</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16771</th>
#       <td>11192834</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16770</th>
#       <td>11192140</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Vendedores por Títulos de Produto</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>ocorrencias_unicas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10957</th>
#       <td>Lembrancinha Batizado</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>11234</th>
#       <td>Lembrancinha Maternidade</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>5034</th>
#       <td>Caneta Personalizada</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>15791</th>
#       <td>Porta Maternidade</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>11691</th>
#       <td>Lembrancinha de batizado</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>11774</th>
#       <td>Lembrancinha maternidade</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>12147</th>
#       <td>Lembrança Batizado</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>11609</th>
#       <td>Lembrancinha de Batizado</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>16005</th>
#       <td>Porta maternidade</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>11071</th>
#       <td>Lembrancinha Chá de Bebê</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Tags por Produto</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>ocorrencias_unicas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>361</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16779</th>
#       <td>11197600</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16777</th>
#       <td>11196802</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16776</th>
#       <td>11196229</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16775</th>
#       <td>11193657</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16774</th>
#       <td>11193421</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16773</th>
#       <td>11193205</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16772</th>
#       <td>11192919</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16771</th>
#       <td>11192834</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>16770</th>
#       <td>11192140</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Tags por Títulos de Produto</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>ocorrencias_unicas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10957</th>
#       <td>Lembrancinha Batizado</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>5034</th>
#       <td>Caneta Personalizada</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>11234</th>
#       <td>Lembrancinha Maternidade</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>15791</th>
#       <td>Porta Maternidade</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>11609</th>
#       <td>Lembrancinha de Batizado</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>11691</th>
#       <td>Lembrancinha de batizado</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>12147</th>
#       <td>Lembrança Batizado</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>11655</th>
#       <td>Lembrancinha de Maternidade</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>19752</th>
#       <td>Trocador Americano</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>6598</th>
#       <td>Copo Long Drink 350ml Personalizado</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Para complementar a análise, a seguir verifica-se o comportamento dos atributos dos produtos ao longo do tempo.

# %%
def count_product_feature_changes(base_frame: pd.DataFrame, feature_columns: List[str]) -> pd.DataFrame:

    agg_occurrences_frame = (
        base_frame
        [['product_id']]
        .assign(ocorrencias=1)
        .groupby(['product_id'])
        .sum()
        .reset_index()
    )

    for column in feature_columns:
        agg_changes_frame = (
            base_frame
            [['product_id', column]]
            .drop_duplicates()
            [['product_id']]
            .assign(**{f'mudancas_{column}':1})
            .groupby(['product_id'])
            .sum()
            .assign(**{f'mudancas_{column}': lambda f: f[f'mudancas_{column}'] - 1})  # Ignora primeiro valor
            .reset_index()
        )

        agg_occurrences_frame = pd.merge(agg_occurrences_frame, agg_changes_frame, on=['product_id'], how='left')

    return (agg_occurrences_frame
            .rename(columns={f'mudancas_{column}':column for column in columns_to_check})
            .assign(mudancas=lambda f: f[columns_to_check].apply(sum, axis=1))
            .assign(porcentagem_mudancas=lambda f: (100 * f['mudancas']/f['ocorrencias']).apply(lambda v: f'{v:.2f}%'))
           )

columns_to_check = ['title', 'concatenated_tags', 'creation_date', 'price', 'weight', 'express_delivery', 'minimum_quantity', 'category']
agg_frame = count_product_feature_changes(frame, columns_to_check)

display(HTML('<h3>Alterações por Atributos</h3>'))
display(agg_frame
        .drop(columns=['product_id', 'ocorrencias', 'mudancas', 'porcentagem_mudancas'])
        .sum()
        .reset_index()
        .T
       )


display(HTML('<h3>Produtos com mudanças</h3>'))
print(f'Total: {len(agg_frame.query("mudancas > 0 and ocorrencias > 1"))}')
display(agg_frame
        .sort_values(by='porcentagem_mudancas', ascending=False)
        .head(5)
       )

display(HTML('<h3>Produtos sem mudanças</h3>'))
print(f'Total: {len(agg_frame.query("mudancas == 0 and ocorrencias > 1"))}')
display(agg_frame
        .query('mudancas == 0')
        .sort_values(by='ocorrencias', ascending=False)
        .head(5)
       )

display(HTML('<h3>Produtos de ocorrência única</h3>'))
print(f'Total: {len(agg_frame.query("ocorrencias == 1"))}')
display(agg_frame
        .query('ocorrencias == 1')
        .sort_values(by='ocorrencias', ascending=False)
        .head(5)
       )

del agg_frame, columns_to_check
# Out:
# <h3>Alterações por Atributos</h3>
#            0                  1              2      3       4  \
# index  title  concatenated_tags  creation_date  price  weight
# 0          0                  0              0   7173    5941
#
#                       5                 6         7
# index  express_delivery  minimum_quantity  category
# 0                   893              5589         0
# <h3>Produtos com mudanças</h3>
# Total: 5264
#       product_id  ocorrencias  title  concatenated_tags  creation_date  price  \
# 14598    9703667            3      0                  0              0      1
# 9237     6176378            2      0                  0              0      1
# 10695    7123847            2      0                  0              0      1
# 1982     1324739            2      0                  0              0      1
# 13112    8736242            2      0                  0              0      1
#
#        weight  express_delivery  minimum_quantity  category  mudancas  \
# 14598       0                 0                 1         0         2
# 9237        0                 0                 0         0         1
# 10695       0                 0                 0         0         1
# 1982        0                 0                 0         0         1
# 13112       0                 0                 0         0         1
#
#       porcentagem_mudancas
# 14598               66.67%
# 9237                50.00%
# 10695               50.00%
# 1982                50.00%
# 13112               50.00%
# <h3>Produtos sem mudanças</h3>
# Total: 8
#       product_id  ocorrencias  title  concatenated_tags  creation_date  price  \
# 21572   14299665            2      0                  0              0      0
# 8343     5574421            2      0                  0              0      0
# 22864   15179518            2      0                  0              0      0
# 3829     2546370            2      0                  0              0      0
# 21457   14221649            2      0                  0              0      0
#
#        weight  express_delivery  minimum_quantity  category  mudancas  \
# 21572       0                 0                 0         0         0
# 8343        0                 0                 0         0         0
# 22864       0                 0                 0         0         0
# 3829        0                 0                 0         0         0
# 21457       0                 0                 0         0         0
#
#       porcentagem_mudancas
# 21572                0.00%
# 8343                 0.00%
# 22864                0.00%
# 3829                 0.00%
# 21457                0.00%
# <h3>Produtos de ocorrência única</h3>
# Total: 19884
#       product_id  ocorrencias  title  concatenated_tags  creation_date  price  \
# 2           2102            1      0                  0              0      0
# 16772   11192919            1      0                  0              0      0
# 16780   11200200            1      0                  0              0      0
# 16779   11197600            1      0                  0              0      0
# 16778   11197230            1      0                  0              0      0
#
#        weight  express_delivery  minimum_quantity  category  mudancas  \
# 2           0                 0                 0         0         0
# 16772       0                 0                 0         0         0
# 16780       0                 0                 0         0         0
# 16779       0                 0                 0         0         0
# 16778       0                 0                 0         0         0
#
#       porcentagem_mudancas
# 2                    0.00%
# 16772                0.00%
# 16780                0.00%
# 16779                0.00%
# 16778                0.00%

# %% [markdown]
#  A partir dos dados apresentados, é possível entender:
#  - Um mesmo produto pode ser vendido por mais de um vendedor?
#  > Aparentemente não.
#  - O título de um produto se repete entre vendedores diferentes?
#  > Há vários produtos vendidos por diferentes pessoas.
#  - Um produto pode apresentar *tags* diferentes?
#  > *Tags* não parecem variar para o mesmo produto.
#  - Produtos com títulos diferentes podem apresentar *tags* diferentes?
#  > Sim, há diversidade de *tags, mesmo entre produtos com o mesmo título.
#  - Desconsiderando atributos relacionados às buscas ou às interações, quais atributos costumam variar para um mesmo produto ao longo do tempo?
#  > Exceto por itens que só têm uma interação, praticamente todos os produtos possuem mudanças em atributos. Os atributos que variam são:
#  >  - Preço (*price*);
#  >  - Peso (*weight*);
#  >  - Pronta entrega (*express_delivery*);
#  >  - Quantidade mínima (*minimum_quantity*).

# %% [markdown]
# ## Entendimento sobre *Tags*
#
# Nesta seção serão exploradas as características das *tags*. O primeiro passo é entender a distribuição do tamanho e identificar casos com texto mais longo, que devem permitir um entendimento melhor do desafio que será decompor as *tags* novamente.
#
# Algumas das questões que se quer responder:
#  - Há *tags* compostas por múltiplas palavras?
#  - É possível restaurar *tags* com múltiplas palavras (caso existam)?
#  - As *tags* estão tratadas?
#  - Há grande variação na quantidade de *tags* por produto?

# %%
# Criar data frame com o tamanho das tags únicas
raw_tags_frame = (
    frame
    [['concatenated_tags']]
    .drop_duplicates()
    .assign(tamanho=lambda f: f['concatenated_tags'].apply(lambda x: len(str(x)) if not pd.isna(x) else 0))
)

# Analisar tags concatenadas por tamanho
display(HTML('<h4>As Tags Concatenadas Mais Longas</h4>'))

sub_frame = (
    raw_tags_frame
    .sort_values(by='tamanho', ascending=False)
    .head(5)
)

for i, item in sub_frame.iterrows():
    print(f' - Tamanho: {item["tamanho"]} | Conteúdo: {item["concatenated_tags"]}\n')

# Usar a sumarização numérica do tamanho das tags concatenadas
display(HTML('<h4>Resumo das Tags Concatenadas Únicas</h4>'))
display(raw_tags_frame[['tamanho']].describe())

# Verificar se há presença de acentuação
display(HTML('<h4>Registros de Tags com Acentuação</h4>'))
search_pattern = re.compile(r'[áãàéíóõç]', flags=re.IGNORECASE)

display(
    raw_tags_frame
    .loc[lambda f: f['concatenated_tags'].apply(lambda x: search_pattern.search(str(x)) != None)]
    .head(5)
)


# Mostrar histograma com a distribuição dos tamanhos
display(HTML('<h4>Distribuição do Tamanho das Tags Concatenadas Únicas</h4>'))
(
    raw_tags_frame
    ['tamanho']
    .hist()
)


del raw_tags_frame, sub_frame
# Out:
# <h4>As Tags Concatenadas Mais Longas</h4>
#  - Tamanho: 870 | Conteúdo: chaveiros plantinhas joaquim almofada 2 anos bernardo formatura alfabeto garotinho ideias casamento festa bosque aniversario 1 ano marina dino decoracoes cha marcela aniversario victor thais niver 90 60 gravity falls batizado lembrancinha casamento toy stories niver 33 lembrancinhas maternidade cha bebe lhama esther 1 ano cha bebe giulia casamento rustico lembrancinhas casorio lembrancinha jardim encantado lembrancas presentear festa baby inspirations suculentas taca cha bebe aniversario theo niver brindes filha leve noivado aniversario mauri 41 anos cha lorenzo lembrancinhas casamento convite padrinhos lembrancinha maternidade lembrancinhas maite 43 ju t anne 1 dinossauros bat alicia bebe festa passarinho festas luisa festa bel aniversario luiza lembrancinhas casamento batizado arthur suculenta lembranca saquinho cha 40 enfermagem pandinha baby lembrancinha
#
#  - Tamanho: 695 | Conteúdo: decoracao quarto meninas lulu girl banquinhos olhinhos decoracao melinda liv manu quarto isis casa banquinho quarto alice quadros diversos fofura mimos escultura bolsas mdf presilhas bebes cute almofadas quarto criancas nenis coisas bebe quarto nenem banco kit berco candy laura quarto quarto isabel decoracao quarto amanda organizador brinquedos quarto valentina bancos decor banqueta banquinhos gabi fofurices picnin bebe quarto sophia rihanna decoracao quarto iza roupas festa valentina 2018 enfeites alice achados quarto manu quarto alicia noibo nuvem/arco-iris//unicornio isabeli kit higiene decoracao quarto enxoval catarina lavinia baby quarto heloisa quarto candy colors decoracao marina
#
#  - Tamanho: 688 | Conteúdo: casamento chris rody festa elis bem casado queijo vinho cha liz renovacao votos casamento praia decoracao cerimonia cactos suculentas 2 anos bernardo paleta madrinhas casamento leidia lembrancinha casamento larisse safari casamento tropical aniversario duda quarto belli casamento boho presentes lembrancinhas plantas lembrancinhas bosque 40 anos casamento casamento carol lembrancinhas dorcas lindinhas lembrancinha cha cozinha floresta jardim encantado suculentas sonhos casamento 2019 suculentas cactos lembrancinhas raposa aniversario pedro eleitos casamento favoritos lembracinhas aniversario secreta lembrancas casamento isis casamento andressa coisitas casamento lembrancinha 43 ju
#
#  - Tamanho: 583 | Conteúdo: necessaires decoracao necessarie casamento madrinhas wedding presente dia secretarias casamento #nanda&nim padrinhos convites padrinhos madrinhas lembranca madrinhas necessaire casamento necessaire presentes padrinhos casamento lany toalhinha necessaries porta maternidade convites lembrancinha madrinhas canecas casorio opcao lembranca padrinhos gravata casamento lembrancinhas itens desejo presente madrinhas madrinhas presente convite padrinhos dia noivado saches casorio vivi jonatas necessaire madrinha ideias necessaire pro casamento casamento mirela jose weverton lembrancinha
#
#  - Tamanho: 507 | Conteúdo: caneca cha bar designer aluguel banner canecas retro cha bebe cha fraldas lembranca maternidade canecas personalizadas caricatura caneca rosca caneca casamento squeeze cantil canecas personagens tv jogo memoria caneca empresas igrejas paineis festas display totem kit decoracao mesa infantil caneca caricatura caneca escolas cofrinho painel pvc canecas casamento serigrafia caneca debutante servicos graficos brindeiros canecas porcelana presentes convites tags copos personalizados caneca foto caneca bodas
# <h4>Resumo das Tags Concatenadas Únicas</h4>
#             tamanho
# count  20255.000000
# mean      49.407801
# std       41.519068
# min        0.000000
# 25%       24.000000
# 50%       38.000000
# 75%       62.000000
# max      870.000000
# <h4>Registros de Tags com Acentuação</h4>
# Empty DataFrame
# Columns: [concatenated_tags, tamanho]
# Index: []
# <h4>Distribuição do Tamanho das Tags Concatenadas Únicas</h4>

# %% [markdown]
# Conforme observado, a grande maioria das *tags* têm tamanho menor do que 100 caracteres. No entanto, há casos em que o valor excede 800 caracteres.
#
# Considerando esses casos com maior tamanho, é possível notar alguns pontos:
#  - O texto das *tags* já está tratado com relação à captalização das letras e remoção de acentos, mas há outros caracteres especiais envolvidos (e.g., *'*, *[*, *]* e *?*);
#  - Exceto quando há o uso de '_' ou outros caracteres especiais, não é possível reverter facilmente *tags* compostas (e.g., 'cha de bebe' e 'bem casado');
#  - Não basta separar as *tags* por espaço, é preciso usar múltiplos caracteres para fazer a decomposição das *tags*.
#
# A seguir, as *tags* serão segmentadas e analisadas.

# %%
agg_frame = (
    frame
    .drop_duplicates('product_id')
    [['concatenated_tags']]    
    .assign(registros=1)
    .groupby('concatenated_tags')
    .sum()
    .reset_index()
    .sort_values(by='registros', ascending=False)
)

tag_split_pattern = re.compile(r"(\s|[-/,;.()_])")

exploded_frame = (
    frame
    .drop_duplicates('product_id')
    .assign(tag=lambda f: f['concatenated_tags'].apply(lambda x: tag_split_pattern.split(str(x))))    
    .explode('tag')
    .loc[lambda f: f['tag'].apply(lambda x: len(x.strip()) > 0)]
)

agg_exploded_frame =(
    exploded_frame
    [['tag']]
    .assign(registros=1)
    .groupby('tag')
    .sum()
    .reset_index()
    .sort_values(by='registros', ascending=False)
)

display_side_by_side([agg_frame.head(20),
                      agg_exploded_frame.head(20)], 
                     ['Tags Concatenadas',
                      'Tags Separadas'],
                     padding=50)

del agg_frame, agg_exploded_frame
# Out:
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Tags Concatenadas</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>concatenated_tags</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7417</th>
#       <td>dia pais</td>
#       <td>254</td>
#     </tr>
#     <tr>
#       <th>11603</th>
#       <td>lembrancinhas</td>
#       <td>138</td>
#     </tr>
#     <tr>
#       <th>2140</th>
#       <td>batizado</td>
#       <td>78</td>
#     </tr>
#     <tr>
#       <th>19142</th>
#       <td>tapetes</td>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>6995</th>
#       <td>decoracao</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>4966</th>
#       <td>casamento</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>7499</th>
#       <td>dia professores</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>2715</th>
#       <td>bebe</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>6727</th>
#       <td>cortinas</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>14170</th>
#       <td>natal</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>18325</th>
#       <td>sandalia dia pais</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>19185</th>
#       <td>tapetes croche</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>9232</th>
#       <td>formatura</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>16269</th>
#       <td>porta maternidade</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>5490</th>
#       <td>cha bebe</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>1228</th>
#       <td>aniversario</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>933</th>
#       <td>almofadas</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>6851</th>
#       <td>croche</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>3473</th>
#       <td>branca neve</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>11398</th>
#       <td>lembrancinha</td>
#       <td>21</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Tags Separadas</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tag</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>972</th>
#       <td>bebe</td>
#       <td>3613</td>
#     </tr>
#     <tr>
#       <th>4008</th>
#       <td>lembrancinhas</td>
#       <td>3311</td>
#     </tr>
#     <tr>
#       <th>4495</th>
#       <td>maternidade</td>
#       <td>2897</td>
#     </tr>
#     <tr>
#       <th>2845</th>
#       <td>festa</td>
#       <td>2842</td>
#     </tr>
#     <tr>
#       <th>3841</th>
#       <td>kit</td>
#       <td>2100</td>
#     </tr>
#     <tr>
#       <th>4004</th>
#       <td>lembrancinha</td>
#       <td>1983</td>
#     </tr>
#     <tr>
#       <th>2182</th>
#       <td>decoracao</td>
#       <td>1864</td>
#     </tr>
#     <tr>
#       <th>1528</th>
#       <td>casamento</td>
#       <td>1857</td>
#     </tr>
#     <tr>
#       <th>1645</th>
#       <td>cha</td>
#       <td>1847</td>
#     </tr>
#     <tr>
#       <th>946</th>
#       <td>batizado</td>
#       <td>1651</td>
#     </tr>
#     <tr>
#       <th>585</th>
#       <td>aniversario</td>
#       <td>1621</td>
#     </tr>
#     <tr>
#       <th>606</th>
#       <td>anos</td>
#       <td>1440</td>
#     </tr>
#     <tr>
#       <th>2273</th>
#       <td>dia</td>
#       <td>1304</td>
#     </tr>
#     <tr>
#       <th>5834</th>
#       <td>quarto</td>
#       <td>1216</td>
#     </tr>
#     <tr>
#       <th>5635</th>
#       <td>porta</td>
#       <td>1155</td>
#     </tr>
#     <tr>
#       <th>5006</th>
#       <td>niver</td>
#       <td>1107</td>
#     </tr>
#     <tr>
#       <th>5425</th>
#       <td>personalizada</td>
#       <td>972</td>
#     </tr>
#     <tr>
#       <th>5205</th>
#       <td>pais</td>
#       <td>939</td>
#     </tr>
#     <tr>
#       <th>1517</th>
#       <td>casa</td>
#       <td>913</td>
#     </tr>
#     <tr>
#       <th>5272</th>
#       <td>parede</td>
#       <td>908</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Para verificar se há casos adicionais de *tags* que não foram corretamente segmentadas, alguns critérios adicionais são utilizados para filtrar e mostrar resultados.

# %%
filtered_exploded_frame =(
    exploded_frame
    [['tag']]
    .drop_duplicates()
    .assign(tamanho=lambda f: f['tag'].apply(lambda x: len(str(x)) if not pd.isna(x) else 0))
    .sort_values(by='tamanho', ascending=False)
    .head(20)
)

display_side_by_side([filtered_exploded_frame],
                     ['Tags Individuais'],
                     padding=20)

del filtered_exploded_frame
# Out:
#                       <div style='display:block;float:left;padding:0 20px 0 0;text-align:center'>
#                          <h3>Tags Individuais</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tag</th>
#       <th>tamanho</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8529</th>
#       <td>querooooooooooooooooooo</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>17811</th>
#       <td>niver1anofernandinho</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>25582</th>
#       <td>especialdeficiencia</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>20073</th>
#       <td>krskrakrskrskrskrs</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>1389</th>
#       <td>angel'smbrancinhas</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>2970</th>
#       <td>lembrancinhaslary</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>11187</th>
#       <td>confraternizacao</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>sacolametalizada</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>32713</th>
#       <td>infantiladesivos</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>4629</th>
#       <td>computadorizados</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>5637</th>
#       <td>cadernecaderneta</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>2165</th>
#       <td>maternidadetema</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>13926</th>
#       <td>selena1gabriel3</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>15177</th>
#       <td>lembranca1pedro</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>11205</th>
#       <td>definitivamente</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>3119</th>
#       <td>aniversariantes</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>8731</th>
#       <td>odontopediatria</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>21733</th>
#       <td>organizacionais</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>1055</th>
#       <td>casa&amp;escritorio</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>29457</th>
#       <td>impressionistas</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Como as tags individuais mais longas indicam, há necessidades adicionais de tratamentos, a exemplo de *querooooooooooooooooooo*, que poderia ter eliminação de caracteres repetidos. Adicionalmente, há  itens que precisariam ter uma separação adicional feita, mas que não empregam algum caractere especial para indicar o ponto de separação (e.g., *niver1anofernandinho* e *especialdeficiencia*). Para esses casos, seria preciso trabalhar em um mecanismo de divisão que encontre uma ou mais separações que gerassem palavras com algum sentido próprio.

# %%
agg_exploded_frame =(
    exploded_frame
    [['product_id']]
    .assign(registros=1)
    .groupby('product_id')
    .sum()
    .reset_index()
    .sort_values(by='registros', ascending=False)
)

display_side_by_side([agg_exploded_frame.head(10),
                      pd.DataFrame(agg_exploded_frame['registros'].describe())],
                     ['Produtos com mais Tags',
                      'Sumarização das Tags'],
                     padding=100)

del agg_exploded_frame
# Out:
#                       <div style='display:block;float:left;padding:0 100px 0 0;text-align:center'>
#                          <h3>Produtos com mais Tags</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12414</th>
#       <td>8271183</td>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th>8082</th>
#       <td>5405748</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>11052</th>
#       <td>7360718</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>13237</th>
#       <td>8814150</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>6341</th>
#       <td>4219999</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>7877</th>
#       <td>5267447</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>24209</th>
#       <td>16070144</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>8505</th>
#       <td>5689644</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>20866</th>
#       <td>13852121</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>14639</th>
#       <td>9730357</td>
#       <td>61</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 100px 0 0;text-align:center'>
#                          <h3>Sumarização das Tags</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>25156.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5.830180</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>5.364394</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>4.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>7.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>115.000000</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Como resultado da análise, é possível responder as questões feitas anteriormente:
#  - Há *tags* compostas por múltiplas palavras?
#    > Sim. Por exemplo "chá de bebê" e "bem casado".
#
#  - É possível restaurar *tags* com múltiplas palavras (caso existam)?
#    > Algumas sim, como as separadas por "_". Outras, separadas por espaço, não são de modo simples (podem ser usando NER ou outras formas de análise).
#
#  - As *tags* estão tratadas?
#    > São com relação a acentuação, no entanto, há caracteres especiais em uso. Adicionalmente, há casos de *tags* bastante numerosas (conjunto com mais de 800 caracteres) e deve ser preciso fazer algum tipo de poda de relevância para tornar o resultado de buscas por similaridade.
#
#  - Há grande variação na quantidade de *tags* por produto?
#    > Sim. 50% têm até 4 *tags*, mas há produtos com até 115.

# %% [markdown]
# ## Entendimento sobre Buscas
#
# Esta seção irá explorar mais características relacionadas à busca, para se obter percepções que ajudem a trabalhar no segundo modelo de classificação.
#
# Algumas das questões que se quer responder são:
#  - Qual a repetição dos critérios de busca?
#  - É possível explorar alguns exemplos de busca e ver a exploração através de páginas e posições de itens?
#  - Qual a distribuição de quantidade de termos nas buscas?
#  - Qual a sobreposição entre os termos das buscas e outros elementos textuais?
#  - As buscas têm variação de formatação?
#  - Há operadores lógicos envolvidos?

# %%
# Criar data frame com o total de ocorrência de cada consulta
agg_frame = (
    frame
    [['query']]
    .assign(registros=1)
    .groupby('query')
    .sum()
    .reset_index()
    .sort_values(by='registros', ascending=False)
)

# Guardar a consulta mais repetida
most_frequent_query = agg_frame.iloc[0]['query']

# Criar dataframe com os registros da busca mais frequente
sub_frame = (
    frame
    .loc[lambda f: f['query'] == most_frequent_query]        
    .drop(columns=['weight', 'express_delivery', 'minimum_quantity', 'period', 'price', 'query'])
    .sort_values(by=['search_page', 'position'])
)

# Exibição dos resultados
display_side_by_side([agg_frame.head(10), sub_frame.head(50)],
                     ['Busca mais repetida', 'Histórico de registros associados à busca mais frequente'],
                     padding=50)

del agg_frame, sub_frame
# Out:
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Busca mais repetida</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>705</th>
#       <td>bolsa maternidade</td>
#       <td>139</td>
#     </tr>
#     <tr>
#       <th>2117</th>
#       <td>dia dos pais</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>4762</th>
#       <td>porta maternidade</td>
#       <td>122</td>
#     </tr>
#     <tr>
#       <th>513</th>
#       <td>batizado</td>
#       <td>121</td>
#     </tr>
#     <tr>
#       <th>3507</th>
#       <td>lembrancinha maternidade</td>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>3736</th>
#       <td>lembrancinhas maternidade</td>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th>3317</th>
#       <td>lembrancinha batizado</td>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>3257</th>
#       <td>lembrancinha</td>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>3419</th>
#       <td>lembrancinha dia dos pais</td>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>5301</th>
#       <td>saida maternidade</td>
#       <td>100</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Histórico de registros associados à busca mais frequente</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>product_id</th>
#       <th>seller_id</th>
#       <th>search_page</th>
#       <th>position</th>
#       <th>title</th>
#       <th>concatenated_tags</th>
#       <th>creation_date</th>
#       <th>view_counts</th>
#       <th>order_counts</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10768</th>
#       <td>2995430</td>
#       <td>9790635</td>
#       <td>1</td>
#       <td>0</td>
#       <td>Kit Bolsa Maternidade</td>
#       <td>lorenzo helena sobrinho kit bolsa maternidade maternidade tudo filha priscilla bolsa quarto bolsa maternidade mm bebe bolsa camponesa</td>
#       <td>2017-05-31 22:24:54</td>
#       <td>3234</td>
#       <td>265.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>5650</th>
#       <td>4111561</td>
#       <td>4204040</td>
#       <td>1</td>
#       <td>1</td>
#       <td>KIT BOLSA MATERNIDADE</td>
#       <td>bolsas cha bebe tata maternidade bolsa maternidade kit maternidade desejos</td>
#       <td>2016-05-25 21:40:50</td>
#       <td>836</td>
#       <td>17.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>14076</th>
#       <td>3664383</td>
#       <td>4204040</td>
#       <td>1</td>
#       <td>1</td>
#       <td>Kit de bolsa Maternidade</td>
#       <td>maternidade brasao bolsas bolsas maternidade enxoval maternidade baby kit kit maternidade brasao bolsa maternidade bolsa kit maternidade desejos rafaela marin</td>
#       <td>2013-12-29 18:43:29</td>
#       <td>4210</td>
#       <td>43.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>32006</th>
#       <td>11623598</td>
#       <td>9790635</td>
#       <td>1</td>
#       <td>2</td>
#       <td>kit bolsa maternidade</td>
#       <td>bolsas favorita kit bolsa maternidade maternidade bolsa bolsa maternidade bebe</td>
#       <td>2017-04-25 22:43:39</td>
#       <td>2212</td>
#       <td>184.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>1128</th>
#       <td>7873052</td>
#       <td>4204040</td>
#       <td>1</td>
#       <td>4</td>
#       <td>Kit de bolsas maternidade</td>
#       <td>bolsas bolsas maternidade kaleb maternidade decoracao miguel kit bolsa maternidade bolsa kit bolsa bebe kit maternidade</td>
#       <td>2017-08-22 12:57:23</td>
#       <td>2885</td>
#       <td>70.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>18804</th>
#       <td>9384525</td>
#       <td>4204040</td>
#       <td>1</td>
#       <td>5</td>
#       <td>KIT BOLSA MATERNIDADE</td>
#       <td>filhos bolsa maternidade bebe kit maternidade kaynan</td>
#       <td>2015-12-02 17:34:16</td>
#       <td>1507</td>
#       <td>24.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>27595</th>
#       <td>1337324</td>
#       <td>4204040</td>
#       <td>1</td>
#       <td>6</td>
#       <td>kit de bolsas maternidade</td>
#       <td>projeto dr baby maternidade kit bolsa maternidade kit bolsa bebe kit maternidade</td>
#       <td>2017-09-24 09:46:37</td>
#       <td>978</td>
#       <td>11.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>4772</th>
#       <td>211465</td>
#       <td>3372737</td>
#       <td>1</td>
#       <td>7</td>
#       <td>Bolsa Maternidade de tecido</td>
#       <td>bolsas maternidade</td>
#       <td>2018-03-22 08:58:36</td>
#       <td>549</td>
#       <td>9.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>27577</th>
#       <td>1613041</td>
#       <td>7732157</td>
#       <td>1</td>
#       <td>9</td>
#       <td>Bolsa Maternidade Média</td>
#       <td>baby porta fralda bolsa maternidade bolsas carteiras bebe</td>
#       <td>2018-06-28 20:13:26</td>
#       <td>1036</td>
#       <td>4.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>13918</th>
#       <td>2345342</td>
#       <td>4151542</td>
#       <td>1</td>
#       <td>10</td>
#       <td>kit bolsa maternidade 2 peças</td>
#       <td>bolsa maternidade personalizada nome bebe bolsa maternidade remily bebe kit bolsa maternidade pecas</td>
#       <td>2017-11-19 00:49:56</td>
#       <td>4325</td>
#       <td>101.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>1340</th>
#       <td>13838536</td>
#       <td>9461775</td>
#       <td>1</td>
#       <td>11</td>
#       <td>Kit bolsas maternidade</td>
#       <td>bolsas colecoes bolsas necessaires bella filhos bolsa isabella kits maternidade bolsa bebe</td>
#       <td>2018-07-18 18:51:53</td>
#       <td>1854</td>
#       <td>16.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>29886</th>
#       <td>13838536</td>
#       <td>9461775</td>
#       <td>1</td>
#       <td>11</td>
#       <td>Kit bolsas maternidade</td>
#       <td>bolsas colecoes bolsas necessaires bella filhos bolsa isabella kits maternidade bolsa bebe</td>
#       <td>2018-07-18 18:51:53</td>
#       <td>1854</td>
#       <td>16.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>6191</th>
#       <td>9761311</td>
#       <td>3718244</td>
#       <td>1</td>
#       <td>12</td>
#       <td>Kit bolsa maternidade personalizada</td>
#       <td>bolsas maternidade bebe bag</td>
#       <td>2018-05-31 17:53:54</td>
#       <td>1398</td>
#       <td>31.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>7827</th>
#       <td>4177139</td>
#       <td>4239312</td>
#       <td>1</td>
#       <td>13</td>
#       <td>Bolsa maternidade</td>
#       <td>bolsas bolsa maternidade</td>
#       <td>2016-03-21 22:07:44</td>
#       <td>274</td>
#       <td>NaN</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>5666</th>
#       <td>12707541</td>
#       <td>8132591</td>
#       <td>1</td>
#       <td>14</td>
#       <td>bolsa maternidade personalizada 2 peças</td>
#       <td>bolsa pro samuel bolsas maternidade bebes noah bolsa bebe</td>
#       <td>2016-09-17 15:50:39</td>
#       <td>1961</td>
#       <td>49.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>11115</th>
#       <td>12707541</td>
#       <td>8132591</td>
#       <td>1</td>
#       <td>14</td>
#       <td>bolsa maternidade personalizada 2 peças</td>
#       <td>bolsa pro samuel bolsas maternidade bebes noah bolsa bebe</td>
#       <td>2016-09-17 15:50:39</td>
#       <td>1969</td>
#       <td>46.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>17848</th>
#       <td>12213957</td>
#       <td>7848368</td>
#       <td>1</td>
#       <td>14</td>
#       <td>Kit Bolsa Maternidade com 2 peças</td>
#       <td>kit bolsas maternidade menina enxoval bolsas isadora bolsa isabella bolsa bolsa maternidade saidas manu</td>
#       <td>2017-05-04 16:12:55</td>
#       <td>1217</td>
#       <td>32.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>30192</th>
#       <td>4128834</td>
#       <td>7290538</td>

# %%
exploded_query_frame = (
    frame
    .drop_duplicates('query')
    .assign(query_term=lambda f: f['query'].apply(lambda x: tag_split_pattern.split(str(x))))    
    .explode('query_term')
    .loc[lambda f: f['query_term'].apply(lambda x: len(x.strip()) > 0)]
)

agg_exploded_frame =(
    exploded_query_frame
    [['query']]
    .assign(registros=1)
    .groupby('query')
    .sum()
    .reset_index()
    .sort_values(by='registros', ascending=False)
)

display_side_by_side([agg_exploded_frame.head(10),
                      pd.DataFrame(agg_exploded_frame['registros'].describe())],
                     ['Buscas com mais termos',
                      'Sumarização dos termos de busca'],
                     padding=100)

del agg_exploded_frame
# Out:
#                       <div style='display:block;float:left;padding:0 100px 0 0;text-align:center'>
#                          <h3>Buscas com mais termos</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2961</th>
#       <td>kit bolsa maternidade categoria bebe nav bolsa maternidade local sao jose do rio preto sp</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>5418</th>
#       <td>suporte de madeira para vasos de parede suporte de madeira para vasos de flores</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>5417</th>
#       <td>suporte de madeira para flores na parede suporte de madeira para vasos de plantas</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>1821</th>
#       <td>cortina voil corta luz blackout blecaute 2 80 x 2 30 branco</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>5706</th>
#       <td>toalha de mesa bordada em ponto cruz com bicos de croche</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1795</th>
#       <td>cortina corta luz black out blecaute 2 80x2 30 cinza pvc</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>2927</th>
#       <td>kit 2 cortina corta luz blackout blecaute pvc 2 80x2 30cores</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>3591</th>
#       <td>lembrancinha patrulha canina categoria aniversario e festas nav painel de aniversario</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1796</th>
#       <td>cortina corta luz blackout blecaute 2 80x2 30 branca pvc</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1798</th>
#       <td>cortina corta luz blackout blecaute 2 80x2 30 cinza pvc</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 100px 0 0;text-align:center'>
#                          <h3>Sumarização dos termos de busca</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>5949.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>3.163389</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.560438</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>3.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>4.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>15.000000</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Verificar a existência de caracteres lógicos ou elementos em caixa alta nas buscas.

# %%
upper_case_frame = (frame
                    [['query']]
                    .loc[lambda f: f['query'].apply(lambda q: any([c.isupper() for c in q]))]
                    .head(5)
                   )

en_operators = [' or ', ' and ', ' & ', 'not ']
pt_operators = [' ou ', ' e ']

en_operators_frame = (frame
                      [['query']]
                      .loc[lambda f: f['query'].apply(lambda q: any([op in q for op in en_operators]))]
                      .head(5)
                     )

pt_operators_frame = (frame
                      [['query']]
                      .loc[lambda f: f['query'].apply(lambda q: any([op in q for op in pt_operators]))]
                      .head(5)
                     )

display_side_by_side([upper_case_frame, en_operators_frame, pt_operators_frame], 
                     ['Buscas com caracteres em caixa alta', 'Buscas com operadores lógicos', 'Buscas com operadores lógicos em português'],
                     padding=50)

del en_operators, pt_operators
del upper_case_frame, en_operators_frame, pt_operators_frame
# Out:
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Buscas com caracteres em caixa alta</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Buscas com operadores lógicos</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>24499</th>
#       <td>rick and morty</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Buscas com operadores lógicos em português</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>query</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>143</th>
#       <td>lembrancas para padrinhos e madrinhas de casamento</td>
#     </tr>
#     <tr>
#       <th>156</th>
#       <td>bela e a fera</td>
#     </tr>
#     <tr>
#       <th>162</th>
#       <td>mini cactos e suculentas</td>
#     </tr>
#     <tr>
#       <th>261</th>
#       <td>lembrancinha masha e o urso</td>
#     </tr>
#     <tr>
#       <th>385</th>
#       <td>lembrancinhas para professor homenageado e paraninfo</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Pela análise, as principais respostas enconradas foram:
#  - Qual a repetição dos critérios de busca?
#  > Até 75% dos das consultas são compostas por 4 elementos. No entanto, há consultas com até 15 termos.
#
#  - É possível explorar alguns exemplos de busca e ver a exploração através de páginas e posições de itens?
#  > Pela pesquisa com maior histórico de interações, foi possível observar ampla cobertura do número de páginas e itens, mas, como observado na descrição estatística das colunas, a exploração costuma ir até a 2ª página e a 16ª posição.
#
#  - Qual a distribuição de quantidade de termos nas buscas?
#  > TODO
#
#  - Qual a sobreposição entre os termos das buscas e outros elementos textuais?
#  > TODO
#
#  - As buscas têm variação de formatação?
#  > Não há buscas com letras em caixa alta, o que pode indicar o pré-processamento das buscas para evitar variação.
#
#  - Há operadores lógicos envolvidos?
#  > Não parece existir evidência de uso de operadores lógicos nas buscas além do uso de "e" e "ou" naturalmente empregado para encadear palavras.

# %% [markdown]
# ## Análise de Categorias
#
# Como as categorias são um recurso determinante para a organização do conteúdo e, neste estudo de caso, a principal informação para a classificação, é importante verificar a distribuição de valores e outros aspectos.
#
# Algumas das questões que se quer entender sobre categorias são:
#  - Há desbalanceamento entre as classes?
#  - Se houver desbalanceamento, ele muda ao longo do tempo?
#  - Como valores numéricos mudam em relação às categorias?
#  - Existem *outliers*, sobretudo com relação a valores extremos, a serem tratados?

# %%
def simple_aggregation(base_frame: pd.DataFrame, columns: List[str] = None) -> pd.DataFrame:
    "Faz a agregação simples por categoria."

    agg_frame = (
        base_frame
        [['category']]
        .assign(registros=1)
        .groupby('category')
        .sum()
        .reset_index()
        .sort_values(by='registros', ascending=False)
    )
    
    return agg_frame

def aggregate_by_columns(base_frame: pd.DataFrame, columns:List[str], group_columns:List[str], records: int=10) -> pd.DataFrame:
    """Função para repetir a agregação dos dados baseados em listas de colunas"""

    agg_frame = (
        base_frame
        [columns]
        .assign(registros=1)
        .groupby(group_columns)
        .sum()
        .reset_index()
        .sort_values(by='registros', ascending=False)
        .head(records)
    )

    return agg_frame



display_side_by_side([simple_aggregation(frame),
                      simple_aggregation(frame.drop_duplicates('product_id'))], 
                     ['Categorias por Cliques',
                      'Categorias por Produtos Únicos'],
                     padding=50)
# Out:
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Categorias por Cliques</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Lembrancinhas</td>
#       <td>15085</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Decoração</td>
#       <td>7598</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Bebê</td>
#       <td>6194</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Papel e Cia</td>
#       <td>2150</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Outros</td>
#       <td>940</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bijuterias e Jóias</td>
#       <td>779</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Categorias por Produtos Únicos</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>category</th>
#       <th>registros</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Lembrancinhas</td>
#       <td>10827</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Decoração</td>
#       <td>6300</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Bebê</td>
#       <td>4754</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Papel e Cia</td>
#       <td>1755</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Outros</td>
#       <td>822</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bijuterias e Jóias</td>
#       <td>698</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Analisando o número de produtos criados por categoria, é possível observar que *Lembrancinhas* se mantém predominante, com algumas raras exceções que ocorrem antes de 2012 ou momentaneamente em 2017. O comportamento das demais categorias também parece se manter relativamente constante, então o desbalanceamento também é constante.

# %%
agg_frame = aggregate_by_columns(frame.drop_duplicates('product_id'), 
                                 columns=['category', 'period'], 
                                 group_columns=['category', 'period'], 
                                 records=len(frame))
sns.lineplot(data=agg_frame, x="period", y="registros", hue="category")
plt.xticks(rotation=60)
del agg_frame

# %% [markdown]
# Como cada categoria deve ter seu próprio conjunto de características, é preciso avaliar como outros valores numéricos se comportam dentro de cada uma delas.

# %%
def plot_numeric_columns_distribution(base_frame: pd.DataFrame, numeric_columns: List[str], 
                                      value_transformation_fn: Callable, title: str) -> None:
    # Contabilizar produtos apenas uma vez e limitar colunas
    agg_frame = (base_frame
                 .drop_duplicates('product_id')
                 [['category'] + numeric_columns]
                )

    # Transformar frame para o formato longo (tidy)
    # Aplicar a função de transformação dos valores
    melted_frame = (pd
                    .melt(agg_frame,
                          id_vars=['category'],
                          value_vars=numeric_columns)
                    .assign(value=lambda f: f['value'].apply(value_transformation_fn))
                   )

    g = sns.stripplot(x="value", y="variable", hue="category", 
                  data=melted_frame, dodge=True, alpha=.25, zorder=1)
    g.set_title(title)
    plt.show()

    
numeric_columns = ['price', 'weight', 'express_delivery', 'minimum_quantity', 'view_counts', 'order_counts']

plot_numeric_columns_distribution(frame, numeric_columns, 
                                  value_transformation_fn=lambda x: min(x, 3000), 
                                  title='Distribuição de Valores por Categorias (Corte de valores a 3000)')
plot_numeric_columns_distribution(frame, numeric_columns, 
                                  value_transformation_fn=lambda x: np.log(x), 
                                  title='Distribuição de Valores por Categorias (Escala Logarítmica)')


# Exibição de casos com maiores valores de atributos por Categorias
for column in ['weight', 'price', 'minimum_quantity', 'view_counts', 'order_counts']: 
    top_items_frame = (frame
                       [['title', 'concatenated_tags', column, 'category']]
                       .sort_values(by=column, ascending=False)
                       .drop_duplicates('category')
                      )
    display_side_by_side([top_items_frame], [f'Produtos com maior valor de \'{column}\' por Categoria'])

del numeric_columns, top_items_frame
# Out:
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Produtos com maior valor de 'weight' por Categoria</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>concatenated_tags</th>
#       <th>weight</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>31383</th>
#       <td>ARMARIO 4 PORTAS - 100% PALLET</td>
#       <td>movelaria decoracao moveis pallet</td>
#       <td>65009.0</td>
#       <td>Decoração</td>
#     </tr>
#     <tr>
#       <th>8356</th>
#       <td>Jogo de sofa de pallets e mesa de centro</td>
#       <td>sofas poltronas</td>
#       <td>60009.0</td>
#       <td>Outros</td>
#     </tr>
#     <tr>
#       <th>15872</th>
#       <td>Berço Cama Montessori Doce Infância</td>
#       <td>berco cama montessori</td>
#       <td>55007.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>30966</th>
#       <td>Logotipo e mascote (Identidade visual combo)</td>
#       <td>identidade visual</td>
#       <td>15000.0</td>
#       <td>Papel e Cia</td>
#     </tr>
#     <tr>
#       <th>13482</th>
#       <td>Caneca de gel congelante 300 ml - 50 un</td>
#       <td>caneca gel congelante personalizado casam</td>
#       <td>11006.0</td>
#       <td>Lembrancinhas</td>
#     </tr>
#     <tr>
#       <th>26999</th>
#       <td>Gaveteiro para jóias com chave</td>
#       <td>moveis porta joias</td>
#       <td>8006.0</td>
#       <td>Bijuterias e Jóias</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Produtos com maior valor de 'price' por Categoria</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>concatenated_tags</th>
#       <th>price</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1124</th>
#       <td>quadro grande abstrato decoração sala 170x180 Cod 994</td>
#       <td>quadros abstratos quadros obra original decoracao sala</td>
#       <td>6289.4200</td>
#       <td>Decoração</td>
#     </tr>
#     <tr>
#       <th>30589</th>
#       <td>Alianças de Casamento em Ouro 18k</td>
#       <td>aliancas ouro 18k</td>
#       <td>6060.1997</td>
#       <td>Bijuterias e Jóias</td>
#     </tr>
#     <tr>
#       <th>19873</th>
#       <td>(KB 0329) Kit berço com tricot</td>
#       <td>theo kit berco menina kit berco menino</td>
#       <td>5565.8600</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>13387</th>
#       <td>Molde de silicone pasta americana ou bis</td>
#       <td>forma silicone decoracao dada molde</td>
#       <td>2998.7100</td>
#       <td>Outros</td>
#     </tr>
#     <tr>
#       <th>381</th>
#       <td>Pasta com Bolsa Personalizada | 250g | 4x0 | 500 unid.</td>
#       <td>pastas simposio</td>
#       <td>998.1900</td>
#       <td>Papel e Cia</td>
#     </tr>
#     <tr>
#       <th>24655</th>
#       <td>750 Canetas Personalizadas + Brinde Grátis ( 511 )</td>
#       <td>canetas personalizadas</td>
#       <td>931.8000</td>
#       <td>Lembrancinhas</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Produtos com maior valor de 'minimum_quantity' por Categoria</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>concatenated_tags</th>
#       <th>minimum_quantity</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>28046</th>
#       <td>tags redondas</td>
#       <td>logo casamento tags melhores</td>
#       <td>3000</td>
#       <td>Papel e Cia</td>
#     </tr>
#     <tr>
#       <th>31926</th>
#       <td>2000 imãs de geladeira - doceria</td>
#       <td>ima geladeira personalizado</td>
#       <td>2000</td>
#       <td>Lembrancinhas</td>
#     </tr>
#     <tr>
#       <th>1969</th>
#       <td>200 Etiquetas Personalizadas Tecido 100% Algodão</td>
#       <td>corujice etiquetas etiquetas personalizadas</td>
#       <td>204</td>
#       <td>Outros</td>
#     </tr>
#     <tr>
#       <th>12357</th>
#       <td>Molde Silicone Ocean Placa Gesso 3D</td>
#       <td>molde silicone 3d silicone silicone 3d molde silicone gesso 3d silicone gesso 3d</td>
#       <td>125</td>
#       <td>Decoração</td>
#     </tr>
#     <tr>
#       <th>8121</th>
#       <td>Lembrancinha Sandália Menina - EVA</td>
#       <td>lembrancinha bebe cha fralda maternidade</td>
#       <td>106</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>17620</th>
#       <td>Par de Alianças de Prata 7mm Banhada a Ouro 24k (ANATOMICAS)</td>
#       <td>aliancas prata banhada ouro 24k</td>
#       <td>58</td>
#       <td>Bijuterias e Jóias</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Produtos com maior valor de 'view_counts' por Categoria</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>concatenated_tags</th>
#       <th>view_counts</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>23668</th>
#       <td>kit bolsa mala bebe maternidade personalizada</td>
#       <td>bolsas cor rosa bolsa baby lembrancas bolsas maternidade gianna madalena nianara bolsa maternidade cha bb princesa iza bebe enxoval colecoes presente manu sofia bella maternidade sarah kit bolsa kit bolsa layla elizete alice melhores</td>
#       <td>34061</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>11159</th>
#       <td>Mini suculentas - PROMOÇÃO</td>
#       <td>chaveiros plantinhas joaquim almofada 2 anos bernardo formatura alfabeto garotinho ideias casamento festa bosque aniversario 1 ano marina dino decoracoes cha marcela aniversario victor thais niver 90 60 gravity falls batizado lembrancinha casamento toy stories niver 33 lembrancinhas maternidade cha bebe lhama esther 1 ano cha bebe giulia casamento rustico lembrancinhas casorio lembrancinha jardim encantado lembrancas presentear festa baby inspirations suculentas taca cha bebe aniversario theo niver brindes filha leve noivado aniversario mauri 41 anos cha lorenzo lembrancinhas casamento convite padrinhos lembrancinha maternidade lembrancinhas maite 43 ju t anne 1 dinossauros bat alicia bebe festa passarinho festas luisa festa bel aniversario luiza lembrancinhas casamento batizado arthur suculenta lembranca saquinho cha 40 enfermagem pandinha baby lembrancinha</td>
#       <td>31372</td>
#       <td>Lembrancinhas</td>
#     </tr>
#     <tr>
#       <th>8529</th>
#       <td>Par Aliança Texturizada Compromisso Namoro em PRATA 950</td>
#       <td>aliancas natali eduardo sthefany querooooooooooooooooooo alianca bd ali noimar fininhas</td>
#       <td>28530</td>
#       <td>Bijuterias e Jóias</td>
#     </tr>
#     <tr>
#       <th>14233</th>
#       <td>Poster A4 Salmo 91</td>
#       <td>religioso poster a4</td>
#       <td>27114</td>
#       <td>Decoração</td>
#     </tr>
#     <tr>
#       <th>20755</th>
#       <td>Caixa namorados</td>
#       <td>thinks enio presentes namorado mateus album presente namorados decoracao aniversario namoro niver convite presente namorados presentes romanticos quadros 1 ano namoro dia namorados amor namorado</td>
#       <td>17332</td>
#       <td>Papel e Cia</td>
#     </tr>
#     <tr>
#       <th>680</th>
#       <td>TECIDO JUTA 100% NATURAL 1.00 LARGURA</td>
#       <td>aniversario davi casamento sizal jutas.. envelope arvore festa lu casamento nay fazendinha moana decor casamento</td>
#       <td>8408</td>
#       <td>Outros</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#                       <div style='display:block;float:left;padding:0 5px 0 0;text-align:center'>
#                          <h3>Produtos com maior valor de 'order_counts' por Categoria</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>concatenated_tags</th>
#       <th>order_counts</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8529</th>
#       <td>Par Aliança Texturizada Compromisso Namoro em PRATA 950</td>
#       <td>aliancas natali eduardo sthefany querooooooooooooooooooo alianca bd ali noimar fininhas</td>
#       <td>2460.0</td>
#       <td>Bijuterias e Jóias</td>
#     </tr>
#     <tr>
#       <th>3450</th>
#       <td>Luminária Marvel / Avengers</td>
#       <td>lorenzo luminarias quadros presente kah ideias presentinhos natal decoracao lu marvel quarto pedro quero pra mim luminarias carrossel</td>
#       <td>1590.0</td>
#       <td>Decoração</td>
#     </tr>
#     <tr>
#       <th>1309</th>
#       <td>Copos Twister 300ml - Personalizados</td>
#       <td>aniver festa laura naiara aniversario leo julia circo lembrancinhas isadora inspiracoes copo thomas bday maci copos personalizdos festas niver 5 anos copo twister 300 ml lembrancas lembrancinhas aniversario heitor festa niver rafa lembrancihas chhg niver festa joao isabela 1 ano festa luiz henrique aniversario unicornio lembrancinhas cha cozinha bosuqe aniversario 1 ano alice lembrancinha niver gaby</td>
#       <td>1039.0</td>
#       <td>Lembrancinhas</td>
#     </tr>
#     <tr>
#       <th>12701</th>
#       <td>Kit Higiene Bebê Passa Fita 8 Pçs Mdf Cru Desmontado +Brinde</td>
#       <td>luiza kit bebe talita bebe julia compra certa grasi outros bebe maria antonia casa comprar kit cecilia sobrinha kit higienico bebe kit higiene mdf coisas luiz fernando kit maternidade kit decoracao quarto helena compras bebe mdf josue emanuel adriana kit higiene artesananato kit baby dreams 3 jhulyeni pedro</td>
#       <td>907.0</td>
#       <td>Bebê</td>
#     </tr>
#     <tr>
#       <th>13438</th>
#       <td>Caixa namorados</td>
#       <td>thinks enio presentes namorado mateus album presente namorados decoracao aniversario namoro niver convite presente namorados presentes romanticos quadros 1 ano namoro dia namorados amor namorado</td>
#       <td>590.0</td>
#       <td>Papel e Cia</td>
#     </tr>
#     <tr>
#       <th>2217</th>
#       <td>Meia De Seda Para Artesanato - 10 Unidades</td>
#       <td>etiqueta material lacos meias fitas lacos tiaras afins henrikey meias tiara faixas bebe faixas arts gorgurao lembrancinha artesanato</td>
#       <td>435.0</td>
#       <td>Outros</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Como pode ser observado, preço e peso possuem um espectro amplo de valores, com grande quantidade de valores extremos.  Entre as categorias, observa-se que 'Bebê' e 'Decoração' possuem os maiores valores para preço e peso. 'Bijuterias e jóias' também possui valores altos, mas tende a ter uma restrição maior com relação ao peso. Em termos de quantidade, os números tendem a ser menores, mas 'Lembrancinhas' e 'Papel e Cia' possuem os maiores valores.
#
# Um ponto que cabe observar é a predominância de móveis entre os produtos mais pesados de cada categoria (exceto por 'Lembrancinhas' e 'Papel e Cia'). Isso mostra o desafio adicional de se lidar com a ambiguidade de categorias de produtos.

# %% [markdown]
# O entendimento das questões iniciais relacionadas a categorias foram:
#  - Há desbalanceamento entre as classes?
#  > Sim. A classe majoritária (Lembrancinhas) é 15 vezes mais numerosa do que a menos frequente (Bijuterias e Jóias).
#
#  - Se houver desbalanceamento, ele muda ao longo do tempo?
#  > Para as 4 categorias mais frequentes, a predomância ao longo do tempo raramente muda. As 2 categorias menos frequente têm mudança ocasional de posição entre si.
#
# - Como valores numéricos mudam em relação às categorias?
#  > Há diferença de comportamento entre as categorias, tanto com relação à distribuição dos valores, quanto à presença de valores mais extremos. Apesar de poder requerer tratamento adicional, isso pode ajudar a melhorar resultados de um modelo de classificação.
#
#  - Existem *outliers*, sobretudo com relação a valores extremos, a serem tratados?
#  > Há grande presença de valores extremos nos dados. Isso indica a necessidade de usar medidas estatísticas mais robustas a outliers.

# %% [markdown]
# ## Análise de Perfil de Produtos de Vendedores
#
# Um ponto que pode ser explorado é o perfil dos vendedores, sobretudo no quão especializado ou diverso ele pode ser com relação às categorias dos produtos.
#
# Algumas das questões que se quer entender sobre categorias são:
#  - Qual a distribuição de produtos por vendedores?
#  - Para vendedores com uma quantidade mínima de produtos, o quão diversos eles são?

# %%
seller_products_frame = (frame
                         [['seller_id', 'product_id']]
                         .drop_duplicates()
                         .assign(produtos=1)
                         .groupby('seller_id')
                         .sum()
                         .reset_index()
                        )

seller_categories_frame = (frame
                         [['seller_id', 'category']]
                         .drop_duplicates()
                         .assign(categories=1)
                         .groupby('seller_id')
                         .sum()
                         .reset_index()
                        )

display_side_by_side([seller_products_frame.describe().T, seller_categories_frame.describe().T],
                     ['Resumo da Quantidade de Produtos por Vendedor', 'Resumo da Quantidade de Categorias por Vendedor'],
                     padding=50
                    )

g = sns.histplot(seller_products_frame['produtos'], cumulative=True)
g. set_title('Distribuição da Quantidade de Produtos por Vendedor')
plt.show()

sns.pairplot(pd.merge(seller_products_frame, seller_categories_frame, on='seller_id', how='inner', validate='one_to_one'),
                 height=3.33)

plt.show()
del seller_products_frame, g
# Out:
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Resumo da Quantidade de Produtos por Vendedor</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>produtos</th>
#       <td>7398.0</td>
#       <td>3.400378</td>
#       <td>5.447651</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>143.0</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>
#
#                       <div style='display:block;float:left;padding:0 50px 0 0;text-align:center'>
#                          <h3>Resumo da Quantidade de Categorias por Vendedor</h3><br />
#                          <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>categories</th>
#       <td>7398.0</td>
#       <td>1.155042</td>
#       <td>0.412913</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>5.0</td>
#     </tr>
#   </tbody>
# </table>
#                       </div>

# %% [markdown]
# Entendimento sobre perfil de venda dos vendedores:
#  - Qual a distribuição de produtos por vendedores?
#  > Ainda que um mesmo vendedor possa ter mais do que 100 produtos, quase 50% dos vendedores têm apenas 1 produto.
#
#  - Para vendedores com uma quantidade mínima de produtos, o quão diversos eles são?
#  > A grande maioria dos vendedores têm apenas 1 produto. Isso ocorre mesmo com o caso do vendedor com 143 produtos.
#
# De modo geral, entende-se que a categoria do produto pode ser algo interessante para se usar para fazer a predição da categoria de um produto. Para este estudo de caso, porém, talvez não seja o ideal considerando o número limitado de vendedores com mais de um produto. Para uso com os dados completos, seria preciso avaliar a coerência das categorizações feitas para os produtos existentes, talvez atribuindo um nível de confiabilidade dos venderoes com relação ao cadastro dos produtos feitos.

# %% [markdown]
# ## Análise Simulada de Mudanças entre Treino e Teste
#
# No primeiro *notebook*, fez-se uma análise superficial do conteúdo do conjunto de dados e a avaliação de elementos que poderiam inflar as métricas de avaliação com o vazamento de informações dos dados de treino nos dados de teste. Nesta seção espera-se ter uma visão sobre o que esperar de mudança ao utilizar os modelos nos dados não vistos, de teste.
#
# Para fazer a análise, é possível simular uma nova divisão temporal entre os dados para identificar pontos de atenção que devem ser observados na hora de criar o modelo. Assim, serão criados dois conjuntos: pseudo-treinamento e pseudo-teste.
#
# O ponto de corte pode ser obtido pela análise feita no primeiro notebook. Considerando que há uma diferença de ~15% entre o período de 2018-05 e 2018-08 (este segundo, é o limite atual do dataset), o primeiro período será utilizado como critério de corte. Apesar da proporção semelhante, é importante observar que os ~15% do conjunto de treino estão espalhados em um intervalo mais amplo de meses, o que deve implicar diferenças ainda maiores do que as que serão observadas neste corte simulado de 3 meses.

# %%
cut_off_period = '2018-05'
split_frame = set_dataset_split(frame, cut_off_period)

pseudo_training_frame = split_frame.loc[lambda f: f['group'] != 'test'].drop(columns=['group'])
pseudo_test_frame = split_frame.loc[lambda f: f['group'] == 'test'].drop(columns=['group'])

print('Conjuntos de dados:')
print(f' - Treinamento Completo: {len(frame)}')
print(f' - Pseudo-Treino: {len(pseudo_training_frame)} ({100 * len(pseudo_training_frame) / len(frame):.2f}%)')
print(f' - Pseudo-Teste: {len(pseudo_test_frame)} ({100 * len(pseudo_test_frame) / len(frame):.2f}%)')

del split_frame
# Out:
# Conjuntos de dados:
#  - Treinamento Completo: 32746
#  - Pseudo-Treino: 27144 (82.89%)
#  - Pseudo-Teste: 5602 (17.11%)

# %%
comparisons = []

for column in frame.columns:

    if column == 'concatenated_tags':
        training_values = set(extract_tokens(pseudo_training_frame, 'concatenated_tags', tag_split_pattern))
        test_values = set(extract_tokens(pseudo_test_frame, 'concatenated_tags', tag_split_pattern))
    else:
        training_values = set(pseudo_training_frame[column].tolist())
        test_values = set(pseudo_test_frame[column].tolist())

    comparisons.append(
        (column,
         len(training_values),
         len(test_values),
         len(training_values & test_values),
         len(training_values | test_values),
         len(training_values - test_values),
         len(test_values - training_values)
        )
    )

comparisons_frame = pd.DataFrame(comparisons, columns=['Column', 'A', 'B', 'A and B', 'A or B','A - B',  'B - A'])

display(HTML('<h3>Comparar valores comuns entre (Pseudo)Treinamento e (Pseudo)Teste</h3>'))
print('Legenda:\n - A = Treinamento\n - B = Teste\n\n')
display(comparisons_frame
        .assign(**{f'A and B %': lambda f: (f['A and B'] / f['A'] * 100).apply(lambda v: f'{v:.2f}%'),
                   f'A or B %': lambda f: (f['A or B'] / f['A'] * 100).apply(lambda v: f'{v:.2f}%'),
                   f'A - B %': lambda f: (f['A - B'] / f['A'] * 100).apply(lambda v: f'{v:.2f}%'),
                   f'B - A %': lambda f: (f['B - A'] / f['A'] * 100).apply(lambda v: f'{v:.2f}%')
                  })
        .style.set_properties(**{'width': '75px'})
       )

del comparisons, comparisons_frame
del pseudo_training_frame, pseudo_test_frame
# Out:
# <h3>Comparar valores comuns entre (Pseudo)Treinamento e (Pseudo)Teste</h3>
# Legenda:
#  - A = Treinamento
#  - B = Teste
# <style  type="text/css" >
# #T_19888_row0_col0,#T_19888_row0_col1,#T_19888_row0_col2,#T_19888_row0_col3,#T_19888_row0_col4,#T_19888_row0_col5,#T_19888_row0_col6,#T_19888_row0_col7,#T_19888_row0_col8,#T_19888_row0_col9,#T_19888_row0_col10,#T_19888_row1_col0,#T_19888_row1_col1,#T_19888_row1_col2,#T_19888_row1_col3,#T_19888_row1_col4,#T_19888_row1_col5,#T_19888_row1_col6,#T_19888_row1_col7,#T_19888_row1_col8,#T_19888_row1_col9,#T_19888_row1_col10,#T_19888_row2_col0,#T_19888_row2_col1,#T_19888_row2_col2,#T_19888_row2_col3,#T_19888_row2_col4,#T_19888_row2_col5,#T_19888_row2_col6,#T_19888_row2_col7,#T_19888_row2_col8,#T_19888_row2_col9,#T_19888_row2_col10,#T_19888_row3_col0,#T_19888_row3_col1,#T_19888_row3_col2,#T_19888_row3_col3,#T_19888_row3_col4,#T_19888_row3_col5,#T_19888_row3_col6,#T_19888_row3_col7,#T_19888_row3_col8,#T_19888_row3_col9,#T_19888_row3_col10,#T_19888_row4_col0,#T_19888_row4_col1,#T_19888_row4_col2,#T_19888_row4_col3,#T_19888_row4_col4,#T_19888_row4_col5,#T_19888_row4_col6,#T_19888_row4_col7,#T_19888_row4_col8,#T_19888_row4_col9,#T_19888_row4_col10,#T_19888_row5_col0,#T_19888_row5_col1,#T_19888_row5_col2,#T_19888_row5_col3,#T_19888_row5_col4,#T_19888_row5_col5,#T_19888_row5_col6,#T_19888_row5_col7,#T_19888_row5_col8,#T_19888_row5_col9,#T_19888_row5_col10,#T_19888_row6_col0,#T_19888_row6_col1,#T_19888_row6_col2,#T_19888_row6_col3,#T_19888_row6_col4,#T_19888_row6_col5,#T_19888_row6_col6,#T_19888_row6_col7,#T_19888_row6_col8,#T_19888_row6_col9,#T_19888_row6_col10,#T_19888_row7_col0,#T_19888_row7_col1,#T_19888_row7_col2,#T_19888_row7_col3,#T_19888_row7_col4,#T_19888_row7_col5,#T_19888_row7_col6,#T_19888_row7_col7,#T_19888_row7_col8,#T_19888_row7_col9,#T_19888_row7_col10,#T_19888_row8_col0,#T_19888_row8_col1,#T_19888_row8_col2,#T_19888_row8_col3,#T_19888_row8_col4,#T_19888_row8_col5,#T_19888_row8_col6,#T_19888_row8_col7,#T_19888_row8_col8,#T_19888_row8_col9,#T_19888_row8_col10,#T_19888_row9_col0,#T_19888_row9_col1,#T_19888_row9_col2,#T_19888_row9_col3,#T_19888_row9_col4,#T_19888_row9_col5,#T_19888_row9_col6,#T_19888_row9_col7,#T_19888_row9_col8,#T_19888_row9_col9,#T_19888_row9_col10,#T_19888_row10_col0,#T_19888_row10_col1,#T_19888_row10_col2,#T_19888_row10_col3,#T_19888_row10_col4,#T_19888_row10_col5,#T_19888_row10_col6,#T_19888_row10_col7,#T_19888_row10_col8,#T_19888_row10_col9,#T_19888_row10_col10,#T_19888_row11_col0,#T_19888_row11_col1,#T_19888_row11_col2,#T_19888_row11_col3,#T_19888_row11_col4,#T_19888_row11_col5,#T_19888_row11_col6,#T_19888_row11_col7,#T_19888_row11_col8,#T_19888_row11_col9,#T_19888_row11_col10,#T_19888_row12_col0,#T_19888_row12_col1,#T_19888_row12_col2,#T_19888_row12_col3,#T_19888_row12_col4,#T_19888_row12_col5,#T_19888_row12_col6,#T_19888_row12_col7,#T_19888_row12_col8,#T_19888_row12_col9,#T_19888_row12_col10,#T_19888_row13_col0,#T_19888_row13_col1,#T_19888_row13_col2,#T_19888_row13_col3,#T_19888_row13_col4,#T_19888_row13_col5,#T_19888_row13_col6,#T_19888_row13_col7,#T_19888_row13_col8,#T_19888_row13_col9,#T_19888_row13_col10,#T_19888_row14_col0,#T_19888_row14_col1,#T_19888_row14_col2,#T_19888_row14_col3,#T_19888_row14_col4,#T_19888_row14_col5,#T_19888_row14_col6,#T_19888_row14_col7,#T_19888_row14_col8,#T_19888_row14_col9,#T_19888_row14_col10,#T_19888_row15_col0,#T_19888_row15_col1,#T_19888_row15_col2,#T_19888_row15_col3,#T_19888_row15_col4,#T_19888_row15_col5,#T_19888_row15_col6,#T_19888_row15_col7,#T_19888_row15_col8,#T_19888_row15_col9,#T_19888_row15_col10{
#             width:  75px;
#         }</style><table id="T_19888_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >A</th>        <th class="col_heading level0 col2" >B</th>        <th class="col_heading level0 col3" >A and B</th>        <th class="col_heading level0 col4" >A or B</th>        <th class="col_heading level0 col5" >A - B</th>        <th class="col_heading level0 col6" >B - A</th>        <th class="col_heading level0 col7" >A and B %</th>        <th class="col_heading level0 col8" >A or B %</th>        <th class="col_heading level0 col9" >A - B %</th>        <th class="col_heading level0 col10" >B - A %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19888_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_19888_row0_col0" class="data row0 col0" >product_id</td>
#                         <td id="T_19888_row0_col1" class="data row0 col1" >21064</td>
#                         <td id="T_19888_row0_col2" class="data row0 col2" >4092</td>
#                         <td id="T_19888_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_19888_row0_col4" class="data row0 col4" >25156</td>
#                         <td id="T_19888_row0_col5" class="data row0 col5" >21064</td>
#                         <td id="T_19888_row0_col6" class="data row0 col6" >4092</td>
#                         <td id="T_19888_row0_col7" class="data row0 col7" >0.00%</td>
#                         <td id="T_19888_row0_col8" class="data row0 col8" >119.43%</td>
#                         <td id="T_19888_row0_col9" class="data row0 col9" >100.00%</td>
#                         <td id="T_19888_row0_col10" class="data row0 col10" >19.43%</td>
#             </tr>
#             <tr>
#                         <th id="T_19888_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_19888_row1_col0" class="data row1 col0" >seller_id</td>
#                         <td id="T_19888_row1_col1" class="data row1 col1" >6592</td>
#                         <td id="T_19888_row1_col2" class="data row1 col2" >1996</td>
#                         <td id="T_19888_row1_col3" class="data row1 col3" >1190</td>
#                         <td id="T_19888_row1_col4" class="data row1 col4" >7398</td>
#                         <td id="T_19888_row1_col5" class="data row1 col5" >5402</td>
#                         <td id="T_19888_row1_col6" class="data row1 col6" >806</td>
#                         <td id="T_19888_row1_col7" class="data row1 col7" >18.05%</td>
#                         <td id="T_19888_row1_col8" class="data row1 col8" >112.23%</td>
#                         <td id="T_19888_row1_col9" class="data row1 col9" >81.95%</td>
#                         <td id="T_19888_row1_col10" class="data row1 col10" >12.23%</td>
#             </tr>
#             <tr>
#                         <th id="T_19888_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_19888_row2_col0" class="data row2 col0" >query</td>
#                         <td id="T_19888_row2_col1" class="data row2 col1" >5623</td>
#                         <td id="T_19888_row2_col2" class="data row2 col2" >2496</td>
#                         <td id="T_19888_row2_col3" class="data row2 col3" >2170</td>
#                         <td id="T_19888_row2_col4" class="data row2 col4" >5949</td>
#                         <td id="T_19888_row2_col5" class="data row2 col5" >3453</td>
#                         <td id="T_19888_row2_col6" class="data row2 col6" >326</td>
#                         <td id="T_19888_row2_col7" class="data row2 col7" >38.59%</td>
#                         <td id="T_19888_row2_col8" class="data row2 col8" >105.80%</td>
#                         <td id="T_19888_row2_col9" class="data row2 col9" >61.41%</td>
#                         <td id="T_19888_row2_col10" class="data row2 col10" >5.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_19888_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_19888_row3_col0" class="data row3 col0" >search_page</td>
#                         <td id="T_19888_row3_col1" class="data row3 col1" >5</td>
#                         <td id="T_19888_row3_col2" class="data row3 col2" >5</td>
#                         <td id="T_19888_row3_col3" class="data row3 col3" >5</td>
#                         <td id="T_19888_row3_col4" class="data row3 col4" >5</td>
#                         <

# %% [markdown]
# Como é possível observar, a separação entre os dados de treinamento e de teste expõe preocupações que devem existir caso se construa um modelo e o aplique a dados de produção.
#
# Algumas preocupações que deverão ser consideradas:
#  - Todos os **produtos** serão novos, então o modelo deve precisar generalizar o aprendizado para ter uma boa eficácia;
#  - Existe repetição de **vendedores** (18%);
#  - Existe grande repetição de entre as **buscas** dos dois conjuntos de dados (38%);
#  - Seja **página de busca** ou **posição**, ambos os conjuntos possuem o mesmo conjunto de valores -- é interessante saber se foi algo controlado na extração ou se o comportamento dos usuários levou a isso;
#  - **Títulos de produtos** são bastante diversos e possuem pouca interseção (~2%);
#  - Há bastante **tags**, que foram comparadas individualmente, compartilhadas entre os dois conjuntos (~38%);
#  - Como esperado, não há **datas de criação** em comum;
#  - A comparação entre os **preços** e **pesos** não é a ideal, mas é possível encontrar valores em comum (18% e 39%). Para preço, deve-se esperar uma mudança do valor ao longo do tempo. Para ambos os atributos, pode-se fazer um estudo no próprio conjunto de treinamento para identificar mudanças de compartamento em geral ou para o mesmo produto do mesmo vendedor;
#  - Como é uma coluna binária, **pronta entrega**  possui ambos os valores compartilhados;
#  - Há diversidade maior de **quantidade mínimas** nos dados de treinamento e há algumas poucas inéditas nos dados de teste;
#  - Há grande quantidade de **contagens** em comum (48%), **para visualizações e pedidos**, entre os conjuntos. Como os dados de teste possuem produtos mais novos e há o janelamento de 30 meses, há uma contribuição para a repetição dos valores.
#  - As **categorias**, que são apenas 6, estão presentes em ambos os conjuntos, como verificado anteriormente;
#  - São 112 **meses** na base de treino e 3 em teste, totalmente disjuntos. Aqui, é possível notar como o período de 3 meses do teste concentra uma quantidade grande de novos produtos em comparação com outros períodos do conjunto de treinamento.
#
# Dentre os itens observados, os que levantaram um ponto de atenção foram os itens query, título e tags. Como esses elementos, de natureza textual, devem ser importantes para ajudar a determinar a categoria do item ou a inteção do usuário, **a baixa interseção de conteúdo entre os conjuntos de treinamento e de teste deve exigir cuidados adicionais para se lidar com palavras ou tags novas**. Para isso, pode ser interessante trabalhar em um nível de sílabas ou transferir conhecimento de um conjunto de palavras mais amplo, seja de algo como um conjunto de dados externo, uma ontologia/tesauro, ou de um modelo de *embeddings* treinado em um conjunto de dados volumoso.
